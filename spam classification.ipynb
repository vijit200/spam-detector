# %%
import pandas as pd
import pickle

# %%
df = pd.read_csv('SMSSpamCollection',sep='\t',header=None)

# %%
df.head()
# Out:
#       0                                                  1
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.columns=['Label','Text']

# %%
df.head()
# Out:
#   Label                                               Text
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # Data cleaning & Text pre processing

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
stopwords_list = ['i',
 'me',
 'my',
 'myself',
 'we',
 'our',
 'ours',
 'ourselves',
 'you',
 "you're",
 "you've",
 "you'll",
 "you'd",
 'your',
 'yours',
 'yourself',
 'yourselves',
 'he',
 'him',
 'his',
 'himself',
 'she',
 "she's",
 'her',
 'hers',
 'herself',
 'it',
 "it's",
 'its',
 'itself',
 'they',
 'them',
 'their',
 'theirs',
 'themselves',
 'what',
 'which',
 'who',
 'whom',
 'this',
 'that',
 "that'll",
 'these',
 'those',
 'am',
 'is',
 'are',
 'was',
 'were',
 'be',
 'been',
 'being',
 'have',
 'has',
 'had',
 'having',
 'do',
 'does',
 'did',
 'doing',
 'a',
 'an',
 'the',
 'and',
 'but',
 'if',
 'or',
 'because',
 'as',
 'until',
 'while',
 'of',
 'at',
 'by',
 'for',
 'with',
 'about',
 'against',
 'between',
 'into',
 'through',
 'during',
 'before',
 'after',
 'above',
 'below',
 'to',
 'from',
 'up',
 'down',
 'in',
 'out',
 'on',
 'off',
 'over',
 'under',
 'again',
 'further',
 'then',
 'once',
 'here',
 'there',
 'when',
 'where',
 'why',
 'how',
 'all',
 'any',
 'both',
 'each',
 'few',
 'more',
 'most',
 'other',
 'some',
 'such',
 'only',
 'own',
 'same',
 'so',
 'than',
 'too',
 'very',
 's',
 't',
 'can',
 'will',
 'just',
 'should',
 "should've",
 'now',
 'd',
 'll',
 'm',
 'o',
 're',
 've',
 'y',
 'ain',
 'aren',
 'ma',
 'mightn',
 "mightn't",
 'mustn',
 "mustn't",
 'needn',
 "needn't",
 'shan',
 "shan't",
 'shouldn',
 "shouldn't",
 'wasn',
 "wasn't",
 'weren',
 "weren't",
 'won',
 "won't",
 'wouldn',
 "wouldn't"]

# %%
from nltk.stem.porter import PorterStemmer

# %%
ps = PorterStemmer()

# %%
corpus = []
for i in range(0,len(df['Text'])):
    review = re.sub('[^a-zA-Z0-9]',' ',df['Text'][i])
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if word not in stopwords_list]
    review = ' '.join(review)
    corpus.append(review)

# %%
len(corpus)
# Out:
# 5572

# %% [markdown]
# # Creating BOW and TF -IDF

# %%
## independet features and dependent

y = pd.get_dummies(df['Label'],drop_first=True)

# %%
y.head()
# Out:
#    spam
# 0     0
# 1     0
# 2     1
# 3     0
# 4     0

# %%
# train test 

from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(corpus,y,test_size=0.2,random_state=42)

# %%
X_train
# Out:
# ['repli win 100 weekli 2006 fifa world cup held send stop 87239 end servic',
#  'hello sort town alreadi dont rush home eat nacho let know eta',
#  'come guoyang go n tell u told',
#  'hey sathya till dint meet not even singl time saw situat sathya',
#  'orang bring rington time chart hero free hit week go rington pic wap stop receiv tip repli stop',
#  'sit mu wait everyon get suit take shower',
#  'finish liao u',
#  'urgent mobil no 07808726822 award 2 000 bonu caller prize 02 09 03 2nd attempt contact call 0871 872 9758 box95qu',
#  'probabl not still go stuff',
#  'wah lucki man save money hee',
#  'hey u still gym',
#  'oh lk tt den take e one tt end cine lor dun wan yogasana oso',
#  'ok lor',
#  'still havent collect dough pl let know go place sent get control number',
#  'stupid not possibl',
#  'u secret admir reveal think u r special call 09065174042 opt repli reveal stop 1 50 per msg recd cust care 07821230901',
#  'amaz rearrang letter give mean dormitori dirti room astronom moon starer eye see elect result lie let recount mother law woman hitler eleven plu two twelv plu one amaz',
#  'call 09090900040 listen extrem dirti live chat go offic right total privaci no one know sic listen 60p min 24 7mp 0870753331018',
#  'never want tell short edg late',
#  'wil reach',
#  'oh yeah diet flew window',
#  'oh shit thought trip loooooool make much sens grin sofa refer sleep couch link sent went trip oh didn babe go celebr rent',
#  'send greet joy happi gr8 even',
#  'armand say get ass epsilon',
#  'aiyah u ok alreadi lar e nydc wheellock',
#  'don know watch film comput',
#  'no heard abt tat',
#  'oop sorri check don mind pick tomo half eight station would ok',
#  'anytim lor',
#  'friendship poem dear dear u r not near hear dont get fear live cheer no tear u r alway dear gud ni8',
#  'yar els thk sort funni thing',
#  'love isn decis feel could decid love life would much simpler less magic',
#  'exact intent',
#  'erm woodland avenu somewher get parish magazin telephon number',
#  'everi day use sleep lt gt',
#  'ju hope true missin co realli missin haven done anyth feel guilti yet',
#  'yup paragon havent decid whether 2 cut yet hee',
#  'hmv bonu special 500 pound genuin hmv voucher answer 4 easi question play send hmv 86688 info www 100percent real com',
#  'final chanc claim ur 150 worth discount voucher today text ye 85023 savamob member offer mobil cs savamob pobox84 m263uz 3 00 sub 16',
#  'sarcasm nt scarcasim',
#  'wherr boytoy',
#  'oh mr sheffield wanna play game okay boss nanni give rais give one',
#  'prepar pleasur',
#  'realli sorri b abl 2 friday hope u find altern hope yr term go ok',
#  'good morn im suffer fever dysentri not abl come offic today',
#  'ur cash balanc current 500 pound maxim ur cash send cash 86688 150p msg cc 08718720201 po box 114 14 tcr w1',
#  'oh forward messag thought send',
#  'k give back thank',
#  'told accentur not confirm true',
#  'hey want anyth buy',
#  '100 date servic cal l 09064012103 box334sk38ch',
#  'use foreign stamp whatev send',
#  'haha hope hear receipt sound gd luck',
#  'no chikku nt yet ya free',
#  'mu like lt gt second',
#  'cant think anyon spare room top head',
#  'sex ur mobil free sexi pic jordan text babe 88600 everi wk get sexi celeb pocketbab co uk 4 pic 16 3 wk 087016248',
#  'today go colleg not abl atten class',
#  'call freephon 0800 542 0578',
#  'don worri finish march ish',
#  '88066 lost 12 help',
#  'ye good crickit mind',
#  'great',
#  'fujitsu seri lifebook good',
#  'arr birthday today wish get oscar',
#  'not',
#  'gonna say no sorri would normal start panic time sorri see tuesday',
#  'no problem renew right away dont know detail',
#  'bad girl ladi',
#  'k actual guy meet sunoco howard right way',
#  'see prolli yeah',
#  'k k special today',
#  'u download fring app',
#  'wait machan call free',
#  'ye complet form clark also utter wast',
#  'sorri got late start way',
#  'howz pain come today said ystrday ice medicin',
#  'hmm shall bring bottl wine keep us amus joke still bring bottl red white see tomorrow',
#  'takin linear algebra today',
#  'aww first time u said u miss without ask miss u first love',
#  'see see mayb reboot ym seen buzz',
#  'hi darlin im way london smash anoth driver big dent im realli miss u u xxx',
#  'ok lor ned 2 go toa payoh 4 2 return smth u wan 2 send wat',
#  'dear hero leav qatar tonit apt opportun pl keep touch lt email gt kerala',
#  'lol forgot eh ye bring babe',
#  'someon conact date servic enter phone fanci find call landlin 09111030116 pobox12n146tf15',
#  'hey got mail',
#  'somewher fredericksburg',
#  'watch telugu movi wat abt u',
#  'urgent tri contact last weekend draw show 900 prize guarante call 09061701851 claim code k61 valid 12hour',
#  'reach home final',
#  'love u 2 littl poci bell sorri love u',
#  'neft transact refer number lt gt rs lt decim gt credit beneficiari account lt gt lt time gt lt gt',
#  'dear got lt gt dollar hi hi',
#  'ill call u 2mrw ninish address icki american freek wont stop callin 2 bad jen k eh',
#  'go colleg pa els ill come self pa',
#  'u dun drive go 2 sch',
#  'gram usual run like lt gt half eighth smarter though get almost whole second gram lt gt',
#  'got smaller capac one quit ex',
#  'not bother trust answer pl',
#  'men like shorter ladi gaze eye',
#  'wan go c doctor',
#  'trip ok quit tire lor uni start today ok 4 co not take modul ju concentr final yr project',
#  'get offici england poli rington colour flag yer mobil tonight game text tone flag 84199 optout txt eng stop box39822 w111wx 1 50',
#  'hope settl new school year wishin gr8 day',
#  'friend want drive em someplac probabl take',
#  'tot u reach liao said shirt',
#  'hi move in2 pub would great 2 c u u cud come',
#  'appt lt time gt not fault u don listen told u twice',
#  'network technic support associ',
#  'oh ho first time u use type word',
#  'wake long ago alreadi dunno thing',
#  'moji inform save live thank',
#  'text pass 69669 collect polyphon rington normal gpr charg appli enjoy tone',
#  'call unabl cal let meet bhaskar deep',
#  'thanx 4 puttin da fone',
#  'cool text',
#  'ya nice readi thursday',
#  'told number gautham',
#  'swhrt u dey hope ur ok tot u 2day love n miss take care',
#  'let know kick',
#  'privat 2004 account statement 07742676969 show 786 unredeem bonu point claim call 08719180248 identifi code 45239 expir',
#  'not stand',
#  'need coz never go',
#  'movi theatr go watch unlimit movi pay',
#  'no ful song lyric',
#  'congrat 2 mobil 3g videophon r call 09061744553 videochat wid ur mate play java game dload polyh music nolin rentl bx420 ip4 5we 150pm',
#  'babe lost tri reboot',
#  'senthil group compani apnt 5pm',
#  'dare chang ring',
#  'ye babi need stretch open pussi',
#  'alright sure let know leav',
#  'sunshin quiz wkli q win top soni dvd player u know countri algarv txt ansr 82277 1 50 sp tyron',
#  'co darren say consid mah ask',
#  'not leav yet ok lor go elsewher n eat u thk',
#  'no need lar ju test e phone card dunno network not gd thk wait 4 si 2 finish bath bath dun disturb u liao u clean ur room',
#  'cool night lemm know around',
#  'rememb hurt day satan impost need pay price may destini keep go u said pray get mind get',
#  'ye sura sun tv lol',
#  '8 latest g still scroung ammo want give new ak tri',
#  'part check iq',
#  'left alreadi orchard',
#  'batteri low babe',
#  'tomorrow not go theatr come wherev u call tell come tomorrow',
#  'got divorc lol',
#  'ye meet town co go gep home could text bu stop don worri finish march ish',
#  'new address appl pair malarki',
#  'draw va dont think',
#  'urgent tri contact u today draw show 800 prize guarante call 09050000460 land line claim j89 po box245c2150pm',
#  'need detail onlin job',
#  'yup anyth lor u dun wan ok',
#  'bday real april',
#  'oooh bed ridden ey think',
#  'hope get away 7 langport still town tonight',
#  'free msg get gnarl barkley crazi rington total free repli go messag right',
#  'u find time bu coz need sort stuff',
#  'stupid auto correct phone',
#  'urgent 2nd attempt contact u 900 prize yesterday still await collect claim call 09061702893 acl03530150pm',
#  'dear not deni word pleas',
#  'ur go 2 bahama callfreefon 08081560665 speak live oper claim either bahama cruis 2000 cash 18 opt txt x 07786200117',
#  'cant pick phone right pl send messag',
#  'macha dont feel upset assum mindset believ one even wonder plan us let life begin call anytim',
#  'sorri call later',
#  'ok',
#  'forward 448712404000 pleas call 08712404000 immedi urgent messag wait',
#  'u send home first ok lor not readi yet',
#  'ok lor u wan go look 4 u',
#  'realli good dhanush rock',
#  'oh well c u later',
#  'hey no leav friday wait ask superior tell',
#  'shop till u drop either 10k 5k 500 cash 100 travel voucher call 09064011000 ntt po box cr01327bt fixedlin cost 150ppm mobil vari',
#  'well gener price lt gt oz let know much want',
#  'not realli dude no friend afraid',
#  'time come',
#  'usf guess might well take 1 car',
#  'urgent 2nd attempt contact u 900 prize yesterday still await collect claim call 09061702893',
#  'seem unnecessarili hostil',
#  'send print out da',
#  'k sure don consent form v',
#  'thank vote sing along star karaok mobil free link repli sing',
#  'norm tomorrow finish 4 15 co st test need sort librari stuff point tomo got letter today access til end march better get move',
#  'im snowboard trip wonder plan get everyon togeth befor go meet greet kind affair cheer',
#  'k head min see',
#  'accident delet messag resend pleas',
#  'yo come carlo soon',
#  'nice new shirt thing wear nudist theme mu',
#  'hurt teas make cri end life die plz keep one rose grave say stupid miss u nice day bslvyl',
#  'hear new divorc barbi come ken stuff',
#  'no one talk',
#  'go join tomorrow',
#  'hello hun ru way im good 2 date guy met walkabout far meet soon how everyon els',
#  'dude sux snake got old raiden got buff',
#  'sindu got job birla soft',
#  'didnt holla',
#  'host base idp linux system',
#  'pleas leav topic sorri tell',
#  'ye mani sweet',
#  'fine thank',
#  'pleas charg mobil get morn',
#  'say happen',
#  'time n smile r two crucial thing life sometim time make us forget smile sometim someon smile make us forget time gud noon',
#  'spoon okay',
#  'bugi oso near wat',
#  'don make life stressful alway find time laugh may not add year life sure add life ur year gud ni8 swt dream',
#  'noth lor bit bore dun u go home earli 2 sleep today',
#  'well not lot thing happen lindsay new year sigh bar ptbo blue heron someth go',
#  'u get messag',
#  'happi birthday may ur dream come true',
#  'ya tel wat ur problem',
#  'r stayin extra week back next wed rugbi weekend hi c u soon',
#  'thinkin someon good no drug',
#  'didn tri g decid not head',
#  'today sunday sunday holiday no work',
#  'luv u soo much u don understand special u r 2 ring u 2morrow luv u xxx',
#  'current lead bid 151 paus auction send custom care 08718726270',
#  'dun wan watch infern affair',
#  'well gonna finish bath good fine night',
#  'dont kick coco',
#  'diet ate 1 mani slice pizza yesterday ugh alway diet',
#  'fine rememb',
#  'no call messag miss call',
#  'sent jd custom servic cum account execut ur mail id detail contact us',
#  'ryder unsold gibb',
#  'mean come chase state watch mani movi want',
#  'sorri call later',
#  'bought test yesterday someth let know exact day u ovul get 2u 2 3wk pl pl dont fret know u r worri pl relax also anyth ur past histori u need tell',
#  'ok enjoy r u home',
#  'good find way',
#  'today system sh get readi well also deep well',
#  'think chennai forgot come auction',
#  'not much textin bout',
#  'ok ask money far',
#  'yavnt tri yet never play origin either',
#  'today vodafon number end 4882 select receiv 350 award number match call 09064019014 receiv 350 award',
#  'havent mu ask u 1st wat meet 4 lunch den u n meet alreadi lor u wan 2 go ask da ge 1st confirm w asap',
#  'symptom u love 1 u like listen song 2 u get stop u see name belov 3 u get angri',
#  'mm food da',
#  'hello wat talk email address',
#  'ow u dey paid 60 400thousad told u would call',
#  'hope feel great pl fill abiola',
#  'got call landlin number ask come anna nagar go afternoon',
#  'lt decim gt not common car better buy china asia find less expens holla',
#  'sunshin hol claim ur med holiday send stamp self address envelop drink us uk po box 113 bray wicklow eir quiz start saturday unsub stop',
#  'stop old man get build snowman snow angel snowbal fight',
#  'u know watchin lido',
#  'ok darlin supos ok worri much film stuff mate babysit call xx',
#  'urgent mobil number award 2000 prize guarante call 09061790121 land line claim 3030 valid 12hr 150ppm',
#  'summer final fanci chat flirt sexi singl yr area get match repli summer free 2 join optout txt stop help08714742804',
#  'also hi wesley',
#  'mark work tomorrow get 5 work hous meet u afterward',
#  'mmm yummi babe nice jolt suzi',
#  'mayb westshor hyde park villag place near hous',
#  'said bad dat e gal know u wat u',
#  'see cup coffe anim',
#  'ok happen behav like',
#  'india go draw seri mani year south african soil',
#  'hi hope good day better night',
#  'suck got plan yo valentin yo valentin',
#  'urgent 4 costa del sol holiday 5000 await collect call 09050090044 toclaim sae tc pobox334 stockport sk38xh cost 1 50 pm max10min',
#  'u guy never invit anywher',
#  'work technic support voic process',
#  'spjanuari male sale hot gay chat cheaper call 08709222922 nation rate 1 5p min cheap 7 8p min peak stop text call 08712460324 10p min',
#  'ye princess go make moan',
#  'good afternoon boytoy goe walk day get polic abstract still wake miss babe',
#  'well know z take care no worri',
#  'dunno lei like dun haf',
#  'bruce amp fowler mom car park long stori',
#  'hiya stu wot u 2 im much trubl home moment evon hate even u wot hell av done wont u tell text bck pleas luv dan',
#  'lookatm thank purchas video clip lookatm charg 35p think better not send video mmsto 32323',
#  'chk ur belovd ms dict',
#  'dun believ wat',
#  'england v macedonia dont miss goal team news txt ur nation team 87077 eg england 87077 tri wale scotland 4txt 1 20 poboxox36504w45wq 16',
#  'nvm ok',
#  'pay lt decim gt lakh',
#  'easi ah sen got select mean good',
#  'aiyah ok wat long got improv alreadi wat',
#  'ye post coupl pic fb still snow outsid wake',
#  'no multimedia messag e mail',
#  'winner valu network custom select receivea 900 prize reward claim call 09061701461 claim code kl341 valid 12 hour',
#  'scotland hope not show jjc tendenc take care live dream',
#  'derek done class',
#  'aight lemm know',
#  'yo watch movi netflix',
#  'don go tell friend not sure want live smoke much spend hour beg come smoke',
#  'gosh pain spose better come',
#  'shall send exe mail id',
#  'ok',
#  'arriv see coupl day lt 3',
#  'u awak snow',
#  'sound like plan cardiff still still cold sit radiat',
#  'thank love wish rock',
#  'no don cancer mom make big deal regular checkup aka pap smear',
#  'boltblu tone 150p repli poli mono eg poly3 1 cha cha slide 2 yeah 3 slow jamz 6 toxic 8 come stop 4 tone txt',
#  'thought put back box',
#  'hey late amk need drink tea coffe',
#  'ye place town meet excit adult singl uk txt chat 86688 150p msg',
#  'tire haven slept well past night',
#  'unni thank dear recharg rakhesh',
#  'k k busi',
#  'ok knacker came home went sleep not good full time work lark',
#  'urgent mobil number award 2000 prize guarante call 09058094454 land line claim 3030 valid 12hr',
#  'hey pple 700 900 5 night excel locat wif breakfast hamper',
#  'u noe wat time e place dat sell 4d close',
#  'free entri gr8prize wkli comp 4 chanc win latest nokia 8800 psp 250 cash everi wk txt great 80878 http www gr8prize com 08715705022',
#  'u made appoint',
#  'camera award sipix digit camera call 09061221066 fromm landlin deliveri within 28 day',
#  'look',
#  'yup noe leh',
#  'yeah probabl still gotta check leo',
#  'nope juz work',
#  'oh fuck juswok bed boatin dock slept wid 25 year old spinout giv u da gossip l8r xxx',
#  'usual iam fine happi amp well',
#  'got shitload diamond though',
#  'cutest girl world',
#  'gud mrng dear hav nice day',
#  'ok dear call chechi',
#  'no need drug anymor',
#  'pay attent',
#  'good morn love go sleep wish great day full feel better opportun last thought babe love kiss',
#  'work pleas call',
#  'haha awesom might need take doin tonight',
#  'like talk pa not abl dont know',
#  'take major role commun outreach rock mel',
#  'no money 4 steve mate',
#  'sound good keep post',
#  'anyway go gym whatev love smile hope ok good day babe miss much alreadi',
#  'time u get',
#  'mysteri solv open email sent anoth batch isn sweeti',
#  'hello lover goe new job happi think wake slave send teas kiss across sea',
#  'someonon know tri contact via date servic find could call mobil landlin 09064015307 box334sk38ch',
#  'not rcv msg chat svc free hardcor servic text go 69988 u get noth u must age verifi yr network tri',
#  'ya cant display intern sub gotta extract',
#  'today voda number end 1225 select receiv 50award match pleas call 08712300220 quot claim code 3100 standard rate app',
#  'not drive rain get caught e mrt station lor',
#  'yeah don go bed back midnight',
#  'get readi moan scream',
#  'call senthil hsbc',
#  'upgrdcentr orang custom may claim free camera phone upgrad loyalti call 0207 153 9153 offer end 26th juli c appli opt avail',
#  'last chanc claim ur 150 worth discount voucher today text shop 85023 savamob offer mobil cs savamob pobox84 m263uz 3 00 sub 16',
#  'hey tmr meet bugi 930',
#  'captain vijaykanth comedi captain tv drunken',
#  'still grand prix',
#  'aight plan come later tonight',
#  '10 min later k',
#  'award sipix digit camera call 09061221061 landlin deliveri within 28day cs box177 m221bp 2yr warranti 150ppm 16 p p 3 99',
#  'gr8 see messag r u leav congrat dear school wat r ur plan',
#  'yup',
#  'ok not much though h friday cant wait dunno wot hell im gonna anoth 3 week becom slob oh wait alreadi done',
#  'dont know bring food',
#  'dont want hear philosophi say happen',
#  'got call landlin number ask come anna nagar go afternoon',
#  'tell friend not come round til like lt gt ish',
#  'dun need pick ur gf',
#  'look addi goe back monday suck',
#  'hank lotsli',
#  'pl dont play other life',
#  'sir wait call free pleas call',
#  'depend individu lor e hair dresser say pretti parent say look gong u kaypoh also dunno wat collect',
#  'ok come home',
#  'r u say order slipper co pay return',
#  'hungri gay guy feel hungri 4 call 08718730555 10p min stop text call 08712460324 10p min',
#  'accident brought em home box',
#  'wait 4 bu stop aft ur lect lar dun c go get car come back n pick',
#  'tot group mate lucki havent repli wat time need leav',
#  'nobodi name peni girl name stori doesn add',
#  'pl need dat slowli vomit',
#  'nice wait text right not gonna pay ticket ya know',
#  'sorri join leagu peopl dont keep touch mean great deal friend time even great person cost great week',
#  'yeah open chat click friend list make list easi pie',
#  'cool last littl get time soon',
#  'oop thk dun haf enuff go check tell',
#  'know shall speak lt gt minut',
#  'hey anyway',
#  'darren say dat u meet da ge den dun meet 4 dinner co later u leav xy feel awkward den u meet 4 lunch lor',
#  'buy today no need c meh',
#  'hi got money da',
#  'pick 5 15pm go taunton still want come',
#  'great church holla get',
#  'mani thing antibiot use chest abdomen gyna infect even bone infect',
#  'da birthdat certif april real date today dont publish shall give special treat keep secret way thank wish',
#  'cmon babe make horni turn txt fantasi babe im hot sticki need repli cost 1 50 2 cancel send stop',
#  'not tel softwar name',
#  'better bb wont use wife doctor',
#  'hello madam',
#  'happen interview',
#  'yeah imma come caus jay want drug',
#  'discount code rp176781 stop messag repli stop www regalportfolio co uk custom servic 08717205546',
#  'pl ask macho much budget bb bold 2 co saw new one lt gt dollar',
#  'said text one time',
#  'win winner mr foley ipod excit prize soon keep eye ur mobil visit www win 82050 co uk',
#  'jesu christ bitch tri give drug answer fuck phone',
#  'stayin troubl stranger saw dave day sort still bloke u gona get girl mr ur mum still think get 2getha',
#  'tessi pl favor pl convey birthday wish nimya pl dnt forget today birthday shija',
#  'no probabl lt gt',
#  'uniqu enough find 30th august www areyouuniqu co uk',
#  'either way work lt gt year old hope doesnt bother',
#  'would ip address test consid comput isn minecraft server',
#  'oop lt gt',
#  'tht god gift bird human hav natur gift frm god',
#  'revers cheat not mathemat',
#  'lt gt pple marri lover becz hav gud undrstndng dat avoid problem sent di 2 u u wil get gud news friday person like tomorrow best day life dont break chain break suffer send lt gt frnd lt gt min whn u read',
#  'littl difficult simpl way enter place',
#  'u',
#  'hi elain today meet confirm',
#  'onum ela pa normal',
#  'two carton u pleas shelv',
#  'mean februari april get place stay don hustl back forth audit season sinc sister move away harlem',
#  'ok theori test go book think 21 may coz thought wanna go jiayin isnt free',
#  'ok gonna head usf like fifteen minut',
#  'text finish long time ago shower er ything',
#  'freemsg hi babi wow got new cam mobi wanna c hot pic fanci chat im w8in 4utxt rpli chat 82242 hlp 08712317606 msg150p 2rcv',
#  'ye last practic',
#  'think ur smart win 200 week weekli quiz text play 85222 cs winnersclub po box 84 m26 3uz 16 gbp1 50 week',
#  'know anthoni bring money school fee pay rent stuff like that need help friend need',
#  'place ur point e cultur modul alreadi',
#  'finish miss plenti',
#  'thought could go dinner treat seem ok',
#  'pub',
#  'may call later pl',
#  'no 1 nokia tone 4 ur mob everi week txt nok 87021 1st tone free get txtin tell ur friend 150p tone 16 repli hl 4info',
#  'oop phone die didn even know yeah like better',
#  'go 4 lunch wif famili aft dat go str 2 orchard lor',
#  'per request maangalyam alaipayuth set callertun caller press 9 copi friend callertun',
#  'dear 0776xxxxxxx u invit xchat final attempt contact u txt chat 86688 150p msgrcvdhg suite342 2land row w1j6hl ldn 18yr',
#  'audri lousi autocorrect',
#  'long quit get like 5 minut day',
#  'dunno lei shd b drive lor co go sch 1 hr oni',
#  'ah well confus thing doesnt thought friend mayb wrong thing alreadi sort invit tho may not come co money',
#  'call dad oredi',
#  'boy late 2 home father power frndship',
#  'free give otherwis nalla adi entey nattil kittum',
#  'want come onlin',
#  'yep derek hous see sunday lt 3',
#  'studi free next weekend',
#  'yup thk cine better co no need 2 go 2 plaza mah',
#  'get threat sale execut shifad rais complaint offici messag',
#  '1st wk free gr8 tone str8 2 u wk txt nokia 8007 classic nokia tone hit 8007 poli nokia 150p poli 200p 16',
#  'piti mood suggest',
#  'done sorri hope next space give everyth want rememb furnitur not around move lock lock leav key jenn',
#  'world run still mayb feel admit mad correct let call life keep run world may u r also run let run',
#  'fight world easi u either win lose bt fightng some1 close u dificult u lose u lose u win u still lose',
#  'don no da what plan',
#  'ay wana meet sat wkg sat',
#  'mmmmm sooooo good wake word morn love mmmm fuck love lion devour kiss across sea',
#  'ok let noe later n ask call u tmr',
#  'hi mom might back later lt gt',
#  'ugh u apolog admit u wrong ask take u back',
#  'make babi yo tho',
#  'yeah got 2 v apologet n fallen actin like spoilt child got caught till 2 go not badli cheer',
#  'winner u special select 2 receiv 1000 cash 4 holiday flight inc speak live oper 2 claim 0871277810810',
#  'sinc side fever vomitin',
#  'din tell u ju 420',
#  'import custom servic announc premier',
#  'promot number 8714714 ur award citi break could win 200 summer shop spree everi wk txt store 88039 skilgm tscs087147403231winawk age16 1 50perwksub',
#  'themob check newest select content game tone gossip babe sport keep mobil fit funki text wap 82468',
#  'two team wait player',
#  'u win 100 music gift voucher everi week start txt word draw 87066 tsc www idew com skillgam 1winaweek age16 150ppermesssubscript',
#  'free msg singl find partner area 1000 real peopl wait chat send chat 62220cncl send stopc 08717890890 1 50 per msg',
#  'late call tomorrow morn take care sweet dream u ummifi bye',
#  'oki',
#  'gonna worri noth give money no use',
#  'free call',
#  'actual get readi leav hous',
#  'lol no ouch wish stay bit longer',
#  'u call alter 11 ok',
#  'intrepid duo great time see soon',
#  'u wake alreadi thanx 4 e tau sar piah quit nice',
#  'dunno lei decid lor abt leona oop tot ben go n msg',
#  'privat 2003 account statement 07808 xxxxxx show 800 un redeem point call 08719899217 identifi code 41685 expir 07 11 04',
#  'much r will pay',
#  'good day pray remov teeth pain maintain stuff',
#  'sm ac blind date 4u rodds1 21 aberdeen unit kingdom check http img sm ac w icmb3cktz8r7 4 no blind date send hide',
#  'actual wait 2 week start put ad',
#  'come home one last time wont anyth trust',
#  'got messag not ignor ye shop',
#  'wiskey brandi rum gin beer vodka scotch shampain wine kudi yarasu dhina vaazhthukk',
#  'horribl bf v hungri',
#  'work technic support voic process network field',
#  'prashanthettan mother pass away last night pray famili',
#  'call say not come today ok tell not fool like ok',
#  'cthen thk shd b enuff still got conclus n content pg n refer b da content pg n cover pg',
#  'sound good finger make difficult type',
#  'bruv hope great break reward semest',
#  'everi monday nxt week vl complet',
#  'someon not smoke everi time smoke last two week call text want smoke',
#  'enjoy urself tmr',
#  'caus not freaki lol',
#  'geeeee internet realli bad today eh',
#  'pleas ask macho price rang want someth new use plu interfu blackberri bold lt gt bb',
#  'fuck babe miss alreadi know let send money toward net need want crave',
#  'cheer callin babe sozi culdnt talkbut wannatel u detail later wenwecan chat properli x',
#  'oh dang didn mean send lol',
#  'beauti sleep help ur pimpl',
#  'miss call caus yell scrappi miss u wait u come home lone today',
#  'hi spoke maneesha v like know satisfi experi repli toll free ye no',
#  'time u wrkin',
#  'lol enjoy role play much',
#  'ok would b love u r sure think wot u want drinkin dancin eatin cinema u wot',
#  'don prize go anoth custom c www c biz 18 150p min polo ltd suit 373 london w1j 6hl pleas call back busi',
#  'awesom see bit',
#  'tht wat wright brother fli',
#  'cours don teas know simpli must see grin keep post prey love smile devour kiss',
#  'thank understand tri tell sura',
#  'wah oki oki muz make use e unlimit haha',
#  'usual take fifteen fuck minut respond ye no question',
#  'life mean lot not love life love peopl life world call friend call world ge',
#  'ye da plm ur offic',
#  'not call hope l8r malaria know miss guy miss bani big pl give love especi great day',
#  'ok tell half hr b4 u come need 2 prepar',
#  'wan come come lor din c stripe skirt',
#  'goodmorn today late lt gt min',
#  'pleas call custom servic repres freephon 0808 145 4742 9am 11pm guarante 1000 cash 5000 prize',
#  'lay man let know miss thought great day send bimbo ugo number ill appreci safe',
#  'east coast',
#  'think thank see tomo',
#  'short cute good person dont tri prove gud noon',
#  'don think get away trek long famili town sorri',
#  'site simul test give tough question test readi',
#  'rington club get uk singl chart mobil week choos top qualiti rington messag free charg',
#  'congrat 2 mobil 3g videophon r call 09063458130 videochat wid ur mate play java game dload polyph music nolin rentl bx420 ip4 5we 150p',
#  'great safe trip dont panic surrend',
#  'die e toot fring',
#  'come right ahmad',
#  'thank 4 continu support question week enter u in2 draw 4 100 cash name new us presid txt an 80082',
#  'hello thanx take call got job start monday',
#  'nope come onlin',
#  'plural noun research',
#  'msg r not time pass silent say think u right also make u think least 4 moment gd nt swt drm shesil',
#  'wonder got onlin love gone net cafe get phone recharg friend net think boytoy',
#  'fyi take quick shower epsilon like lt gt min',
#  'yeah think use gt atm regist not sure anyway help let know sure readi',
#  'come home class right need work shower',
#  'mani lick take get center tootsi pop',
#  'lol ok ill tri send warn sprint dead slow prolli get tomorrow',
#  'ye princess want catch big strong hand',
#  'place man',
#  'pathaya enketa maraikara pa',
#  'gud mrng dear hav nice day',
#  'mm way railway',
#  'u go phone gonna die stay',
#  'come onlin today night',
#  'imagin final get sink bath put pace mayb even eat left also imagin feel cage cock surround bath water remind alway own enjoy cuck',
#  'also andro ice etc etc',
#  'u select stay 1 250 top british hotel noth holiday valu 350 dial 08712300220 claim nation rate call bx526 sw73ss',
#  'job profil seem like bpo',
#  'hamster dead hey tmr meet 1pm orchard mrt',
#  'ur paper today e morn aft',
#  'japanes proverb one u none u must indian version one let none leav final kerala version one stop none make strike',
#  'dear chechi talk',
#  'dear friend sorri late inform today birthday love ar praveesh detail log face book see number lt gt dont miss delici treat',
#  'storm msg wen u lift phne u say hello u knw wt real mean hello name girl ye u knw dat girl margaret hello girlfrnd f grahmbel invnt telphon moral one 4get name person bt not girlfrnd g n g h',
#  'come back thursday yay gonna ok get money cheer oh yeah everyth alright how school call work',
#  'hello boytoy made home constant thought love hope nice visit wait till come home kiss',
#  'free entri 250 weekli comp send word win 80086 18 c www txttowin co uk',
#  'aiyo u poor thing u dun wan 2 eat u bath alreadi',
#  '1 000 cash 2 000 prize claim call09050000327 c rstm sw7 3ss 150ppm',
#  'sorri flake last night shit serious goin roommat tonight',
#  'quit late lar ard 12 anyway wun b drivin',
#  'tuesday night r u 4 real',
#  'go chase run cross street',
#  'g say never answer text confirm deni',
#  'still work go small hous',
#  'think could stop like hour roommat look stock trip',
#  'lol great im get hungri',
#  'would good phone tomo lunchtim shall organis someth',
#  'yesterday true true',
#  'ya nice readi thursday',
#  'hi way u 2day normal way real ur uniqu hope know u 4 rest mylif hope u find wot lost',
#  'today accept day u accept brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd no rpli mean enemi',
#  'u look 4 da lib got stuff havent finish yet',
#  'ok',
#  'loan purpos 500 75 000 homeown tenant welcom previous refus still help call free 0800 1956669 text back help',
#  'no rush not work school rush go hungri',
#  'ok wif co like 2 tri new thing scare u dun like mah co u said not loud',
#  '',
#  'gd luck 4 ur exam',
#  'not campu librari',
#  'no good movi ok leav hourish',
#  'u secret admir look 2 make contact u find r reveal think ur special call 09058094599',
#  'rofl true name',
#  'bit ur smile hppnss drop ur tear sorrow part ur heart life heart like mine wil care u forevr goodfriend',
#  'knew u slept v late yest wake late',
#  'dear mood cant drive brother drive',
#  'work right',
#  'hmmm still dont open',
#  'lol yeah point guess not',
#  'well babe swollen gland throat end',
#  'simpl arithmet not percentag',
#  'yesterday go home',
#  'india win level seri mean record',
#  'dunno dat wat told ok lor',
#  'meet call later',
#  'ye know cheesi song frosti snowman',
#  'pleas call custom servic repres freephon 0808 145 4742 9am 11pm guarante 1000 cash 5000 prize',
#  'no call messag miss call',
#  'happi come noon',
#  'no ye pleas swim',
#  'lol could starv lose pound end day',
#  'life mean lot not love life love peopl life world call friend call world ge',
#  'haven eaten day sit stare juici pizza eat med ruin life',
#  'yeah think',
#  'not thought bout drink tap spile seven pub ga st broad st canal ok',
#  'hi 07734396839 ibh custom loyalti offer new nokia6600 mobil 10 txtauction txt word start no 81151 get 4t',
#  'hate turn fun shop trip annoy day everyth would look hous',
#  'dog must alway wait till end day word run time cell alreadi',
#  'u wan 2 haf lunch da canteen',
#  'home pleas call',
#  'stop get ice cream go back',
#  'slave want take 2 3 pictur today bright light cell phone bright light',
#  'aww must nearli dead well jez iscom todo workand whilltak forev',
#  'one small prestig problem',
#  'no dice art class 6 thru 9 thank though idea time come tomorrow',
#  'freez crave ice fml',
#  'whatsup dont u want sleep',
#  '5 free top polyphon tone call 087018728737 nation rate get toppoli tune sent everi week text subpoli 81618 3 per pole unsub 08718727870',
#  'hi dear call urgnt don know what problem don want work problem least tell wate repli',
#  'mum sent mani mani messag sinc got want know actual get enjoy rest day',
#  'aight text back',
#  'yup leav right back soon',
#  'merri christma babe love ya kiss',
#  'well offici philosoph hole u wanna call home readi save',
#  'great escap fanci bridg need lager see tomo',
#  'free rington repli real poli eg real1 1 pushbutton 2 dontcha 3 babygoodby 4 golddigg 5 webeburnin 1st tone free 6 u join 3 wk',
#  'ye offic da',
#  'done c',
#  'anyth valuabl 2 situat first get second loos',
#  'fine absolutli fine',
#  'talk g x',
#  'k k perform',
#  'send logo 2 ur lover 2 name join heart txt love name1 name2 mobno eg love adam eve 07123456789 87077 yahoo pobox36504w45wq txtno 4 no ad 150p',
#  'oh love soooo good hear omg miss much today sorri problem provid thank tming',
#  'idea soon get convert live',
#  'search 4 happi 1 main sourc unhappi accept life way come u find happi everi moment u live',
#  'smile pleasur smile pain smile troubl pour like rain smile sum1 hurt u smile becoz someon still love see u smile',
#  'realli realli broke oh no amount small even lt gt',
#  'u secret admir look 2 make contact u find r reveal think ur special call 09058094599',
#  'tot u outsid co darren say u come shop cours nice wat ju went sim lim look mp3 player',
#  'get back home',
#  'confirm eat esplanad',
#  'k k sm chat',
#  'waqt se pehl naseeb se zyada kisi ko kuch nahi milta zindgi wo nahi jo hum socht hai zindgi wo hai jo ham jeetey hai',
#  'mobi pub quiz win 100 high street prize u know new duchess cornwal txt first name 82277 unsub stop 1 50 008704050406 sp arrow',
#  'no need ke qi bore izzit suddenli thk',
#  'class lt gt reunion',
#  '500 new mobil 2004 must go txt nokia no 89545 collect today 1 www 4 tc biz 2optout 087187262701 50gbp mtmsg18 txtauction',
#  'happi sad one thing past no good morn',
#  'yup no alreadi thanx 4 print n hand',
#  'yup hey one day fri ask miwa jiayin take leav go karaok',
#  'new theori argument win situat lose person dont argu ur friend kick amp say alway correct',
#  'wan2 win meet greet westlif 4 u m8 current tour 1 unbreak 2 untam 3 unkempt text 1 2 3 83049 cost 50p std text',
#  'tee hee lectur cheeri bye bye',
#  'nokia 7250i get win free auction take part send nokia 86021 hg suite342 2land row w1jhl 16',
#  'freemsg hey buffi 25 love satisfi men home alon feel randi repli 2 c pix qlynnbv help08700621170150p msg send stop stop txt',
#  'oki',
#  'remind get shall',
#  'famili happi',
#  'mani peopl seem special first sight remain special till last sight maintain till life end sh ja',
#  'new tone week includ 1 mcfli ab 2 sara jorg shock 3 smith switch order follow instruct next messag',
#  'go sao mu today done 12',
#  'think ask gym excus lazi peopl jog',
#  'u mean u almost done done wif sleep tot u go take nap yup send liao pick ard 4 smth lor',
#  'great get worri know wonder care person like best life know u r wonder god love',
#  'reach ur home lt gt minut',
#  'alway braini one',
#  'sorri miss call pleas call back',
#  'welcom select o2 servic ad benefit call special train advisor free mobil diall 402',
#  'dear voucher holder claim week offer pc pleas go http www wtlp co uk text ts cs appli',
#  'hello need posh bird chap user trial prod champney put need address dob asap ta r',
#  'brainless babi doll vehicl sariyag drive madok barolla',
#  'class holla later',
#  'u lunch alon bore',
#  'frnd not juz word not mere relationship silent promis say wherevr whenevr forevr gudnyt dear',
#  'thank call forgot say happi onam sirji fine rememb met insur person meet qatar insha allah rakhesh ex tata aig join tissco tayseer',
#  'k sent',
#  'enough troubl sleep',
#  'haf enuff space got like 4 mb',
#  'like made throw smoke friend car one time awesom',
#  'dont understand messag',
#  'not happi say',
#  'babe goe day sip cappuccino think love send kiss across sea',
#  'send text skype later',
#  'mm umma ask vava also come tell play later togeth',
#  'mobil number 5000 claim call us back ring claim hot line 09050005321',
#  'yup free',
#  'no problem talk later',
#  'thank rington order ref number k718 mobil charg 4 50 tone not arriv pleas call custom servic 09065069120',
#  'go bed prin',
#  'sunshin quiz wkli q win top soni dvd player u know countri algarv txt ansr 82277 1 50 sp tyron',
#  'go buy wif meet later',
#  'mobi pub quiz win 100 high street prize u know new duchess cornwal txt first name 82277 unsub stop 1 50 008704050406 sp',
#  'hey kate hope ur ok give u buz wedlunch go outsomewher 4 adrink town cud go 2watershd 4 bit ppl fromwrk bthere love petexxx',
#  'mayb could get book tomo return immedi someth',
#  'don call like lt gt time oh no give us hypertens oh',
#  'k sure get noon see',
#  'love wine dine ladi',
#  'well meant oppos drunken night',
#  'twink bear scalli skin jock call don miss weekend fun call 08712466669 10p min 2 stop text call 08712460324 nat rate',
#  'also cbe pay',
#  'take mokka player',
#  'msg rajini come',
#  'yo yo yo byatch whassup',
#  'let make saturday monday per conveni',
#  'k come nordstrom done',
#  'sorri sent blank msg yup tri 2 seriou studi',
#  'omg joanna freak look thru friend find photo ask stuff myspac haven even log like year',
#  'eat shit wait ur monkey face bitch u asshol',
#  'sir wait letter',
#  'let know chang next 6hr even appendix age rang howev not imposs chill let know 6hr',
#  'home n readi',
#  'yo jp hungri like mofo',
#  'hmm mani unfortun pic obvious arent hot cake kinda fun tho',
#  'hey hey wereth monkeespeopl say monkeyaround howdi gorgeou howu doin foundurself jobyet sausag love jen xxx',
#  'kind took garag centr part exhaust need replac part order n take fix tomo morn',
#  'nvm go wear sport shoe anyway go late leh',
#  'ok call mom instead fun',
#  'wen ur lovabl bcum angri wid u dnt take serious coz angri childish n true way show deep affect care n luv kettoda manda nice day da',
#  'thank hope good day today',
#  'cant pick phone right pl send messag',
#  'cbe realli good nowaday lot shop showroom citi shape good',
#  'check mail mail varma kept copi regard membership take care insha allah',
#  'know serv mean',
#  'want send virtual hug need one',
#  'date sunday',
#  'hey look like wrong one kappa guy number still phone want text see around',
#  'yup not comin',
#  'sent score sopha secondari applic school think think appli research cost also contact joke ogunrind school one less expens one',
#  'kothi print marandratha',
#  'effect irrit ignor',
#  'ask call ok',
#  'whatev juliana whatev want',
#  'hello got st andrew boy long way cold keep post',
#  'no sir 8 hr trip bu last week anoth audit next wednesday think might drive time',
#  'ur physic get',
#  'oki',
#  'u see post facebook',
#  'sorri sir call tomorrow senthil hsbc',
#  'congrat nokia 3650 video camera phone call 09066382422 call cost 150ppm ave call 3min vari mobil 16 close 300603 post bcm4284 ldn wc1n3xx',
#  'wat time u finish ur lect today',
#  'late',
#  '1 thing chang sentenc want 2 concentr educ career im leav',
#  'whenev see still hook',
#  'honeymoon outfit',
#  'thought prap meant anoth one goodo look tomorrow',
#  'dont pick call someth import tell hrishi',
#  'fuuuuck need stop sleepin sup',
#  'well that nice bad cant eat',
#  'way make sure u get train worc foreg street not shrub hill fun night x',
#  'honeybe said sweetest world god laugh amp said wait u havnt met person read msg moral even god crack joke gm gn ge gn',
#  'hey babe far 2 spun 2 spk da mo dead 2 da wrld sleep da sofa day cool nytho tx 4 fonin hon call 2mwen im bk frmcloud 9 j x',
#  'storm msg wen u lift phne u say hello u knw wt real mean hello name girl ye u knw dat girl margaret hello girlfrnd f grahmbel invnt telphon moral one 4get name person bt not girlfrnd g n g h',
#  'think fix send test messag',
#  'queen go royal wed',
#  'brother geniu',
#  'give sec think think',
#  'cloth jewelri trip',
#  'ok arm feel weak cuz got shot go anoth time',
#  'pleas give 2 pick tuesday even 8 ok',
#  'believ true incred txt repli g learn truli amaz thing blow mind o2fwd 18p txt',
#  'realli sorri lit hair fire',
#  'room number wanna make sure knock right door',
#  'shuhui say chang 2 suntec steamboat u noe r u',
#  'hey sexi bun told ador loverboy hope rememb thank sister law meatbal grin love babe',
#  'no wait e car dat bore wat co wait outsid got noth 2 home stuff watch tv wat',
#  'no hour went hair cut',
#  'stop call everyon say might cancer throat hurt talk answer everyon call get one call not babysit monday',
#  'forc eat slice realli not hungri tho suck mark get worri know sick turn pizza lol',
#  'ur face test 1 2 3 4 5 6 7 8 9 lt gt select number tell ur face astrolog wait quick repli',
#  'u workin overtim nigpun',
#  'prakesh know',
#  'dunno wat get 4',
#  'mean still think teju',
#  'great run ttyl',
#  'e msg ju u said thank gift',
#  'not sure still avail though',
#  'realli need 2 kiss u miss u babi ur babi 4eva',
#  'dunno let go learn pilat',
#  'right meanwhil project twin comin',
#  'hi think match',
#  'honey sweetheart darl sexi bun sugar plum loverboy miss boytoy smack ass go gym',
#  'congrat nokia 3650 video camera phone call 09066382422 call cost 150ppm ave call 3min vari mobil 16 close 300603 post bcm4284 ldn wc1n3xx',
#  'get 3 lion england tone repli lionm 4 mono lionp 4 poli 4 go 2 www rington co uk origin n best tone 3gbp network oper rate appli',
#  'want new video handset 750 anytim network min half price line rental camcord repli call 08000930705 deliveri tomorrow',
#  'okay go sleep later',
#  'bar b q store life twat orang dungere came ask want deck got first punch',
#  'come ur home',
#  'sch neva mind u eat 1st lor',
#  'otherwis part time job na tuition',
#  'gonna death gonna leav note say rob fault aveng',
#  'ard 530 lor ok messag lor',
#  'haha cant tmr forfeit haha',
#  'pl full name joke school co fee univers florida seem actual lt gt k pl holla back',
#  'not sure check happen around area',
#  'yeah go bore depress sittin waitin phone ring hope wind drop though scari',
#  'time week ryan',
#  'come room point iron plan weekend',
#  'reach offic around lt decim gt amp mobil problem cann get voic call asa free',
#  'alright thank advic enjoy night tri get sleep',
#  'aaooooright work',
#  'wake lt gt morn',
#  'stop howev suggest stay someon abl give or everi stool',
#  'call said choos futur',
#  'probabl gonna swing wee bit',
#  'hey babe go ever figur go new year',
#  'hahaha use brain dear',
#  'meet u work tel shall work tomorrow',
#  'not finish work yet someth',
#  'urgent pleas call 09061213237 landlin 5000 cash luxuri 4 canari island holiday await collect cs sae po box 177 m227xi 150ppm 16',
#  'wot u 2 bitch',
#  'fuck chicken messag would late woould buzz didn hear word',
#  'love night xxx',
#  'togeth thinkin',
#  'read text sent meant joke read light',
#  'lt gt guess easi enough',
#  'congratul thank good friend u 2 000 xma prize 2 claim easi call 08718726978 10p per minut bt nation rate',
#  'weather',
#  'good word word may leav u dismay mani time',
#  'olol print forum post guy exact prob fix gpu replac hope dont ignor',
#  'hurt n meaning line ever compromis everyth love end love compromis everyth gud mornin',
#  'idk keep say not sinc move keep but head freedom vs respons tire much shit deal bare keep togeth get ad',
#  'watch tv lor',
#  'ride equal unev not mani peski cyclist around time night',
#  'r mani model soni ericson also der lt gt luk good bt forgot modl no',
#  'send naughti pix',
#  'send pic like',
#  'guy no flash go call call madam take care oh',
#  'come n pick 530 ar',
#  'hi di yiju would happi work wif gek1510',
#  'reali sorri don recognis number confus r u pleas',
#  'credit top http www bubbletext com renew pin tgxxrz',
#  'wat da decis',
#  'k tell anyth',
#  'yeah abl text readi meet',
#  'know god creat gap finger one made come amp fill gap hold hand love',
#  'alreadi one guy love',
#  'free entri 2 weekli comp chanc win ipod txt pod 80182 get entri std txt rate c appli 08452810073 detail 18',
#  'hey someth came last min think wun sign tmr hee',
#  'free 1st week entri 2 textpod 4 chanc 2 win 40gb ipod 250 cash everi wk txt pod 84128 ts cs www textpod net custcar 08712405020',
#  'kalli wont play first two odi',
#  'ok may free gym',
#  'still not work time also tri ad zero save check lt gt',
#  'bloodi hell cant believ forgot surnam mr ill give u clue spanish begin',
#  'thanx lot 4 ur help',
#  'might accid tookplac somewher ghodbandar rd traffic move slove plz slip amp don worri',
#  'much ur hdd case cost',
#  'train tomorrow',
#  'well watch shrek 3d b',
#  'watch tv lor nice one like lor',
#  'natalja 25 f invit friend repli ye 440 no 440 see www sm ac u nat27081980 stop send stop frnd 62468',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press 9 copi friend callertun',
#  'great p diddi neighbor come toothpast everi morn',
#  'ever green quot ever told jerri cartoon person irrit u alway one love u vri much fail express gud nyt',
#  'beerag',
#  'day work day except saturday sunday',
#  'u win 100 music gift voucher everi week start txt word draw 87066 tsc www idew com skillgam 1winaweek age16 150ppermesssubscript',
#  'ummmmmaah mani mani happi return day dear sweet heart happi birthday dear',
#  'sorri help',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happi morn',
#  'go take babe',
#  'guessin gonna 9',
#  'no decid peopl care stuff vote care stuff loser',
#  'time tell friend around',
#  'hello good week fanci drink someth later',
#  'ye complet form clark also utter wast',
#  'tirupur da start offic call',
#  'messag truro hospit ext phone phone side',
#  'still pretti weak today bad day',
#  'channel',
#  'ok lor thanx school',
#  'peopl see msg think iam addict msging wrong bcoz don know iam addict sweet friend bslvyl',
#  'mani depend',
#  'give us back id proof lt gt rs wont allow work come home within day',
#  'free msg rington http tm widel com index wml id 1b6a5ecef91ff9 37819 first true18 0430 jul 05',
#  'u ask next sat not make ok lor',
#  'ditto worri say anyth anymor like said last night whatev want peac',
#  'sure neighbor didnt pick',
#  'happen adventur',
#  'first strike red one bird antelop begin toplay fieldof selfindepend believ flower content grow random',
#  'dont know support ass srt thnk think ps3 play usb',
#  'say slowli god love amp need clean heart blood send ten special peopl amp u c miracl tomorrow pl pl',
#  'hi jess dont know work call u im home eve xxx',
#  'chanc realiti fantasi show call 08707509020 20p per min ntt ltd po box 1327 croydon cr9 5wb 0870 nation rate call',
#  'ok',
#  'haha yup hope lose kg mon hip hop go orchard weigh',
#  'alrit jod how revis goin keri bin doin smidgin n e way u wanna cum colleg xx',
#  'freez home yet rememb kiss mom morn love think miss yet',
#  'tell dear happen talk like alian',
#  'good even roger',
#  'oki thanx',
#  'gent tri contact last weekend draw show 1000 prize guarante call 09064012160 claim code k52 valid 12hr 150ppm',
#  'like new mobil',
#  'erutupalam thandiyachu',
#  'jason say cool pick place like hour',
#  'mobil 11 month u r entitl updat latest colour mobil camera free call mobil updat co free 08002986030',
#  'yup elabor safeti aspect issu',
#  'bishan lar nearer no need buy earli co buy gotta park car',
#  'guy car shop flirt got phone number paperwork call text nervou cours may address call boss tell know may get fire',
#  'ye finish watch day live love',
#  'u studi sch go home anyway b go 2 sch later',
#  'excel thought misundrstud frnd knw u hate bt day wen u knw truth u hate urself gn',
#  'lt gt ish minut 5 minut ago wtf',
#  'dear reach',
#  'hi yiju meet u 11 tmr',
#  'think might give miss teach til twelv lectur two damn work thing',
#  'saturday sunday holiday difficult',
#  'tomarrow want got court lt decim gt come bu stand 9',
#  'got take 2 take part wrc ralli oz u lucozad energi text ralli le 61200 25p see pack lucozad co uk wrc itcould u',
#  'oh ok wait 4 lect havent finish',
#  'no problem',
#  'avail soire june 3rd',
#  'custom servic announc recent tri make deliveri unabl pleas call 07090298926 schedul ref 9307622',
#  'lot sick thing go round take easi hope u feel better soon lol',
#  'ok din get ur msg',
#  'mathew tait edward anderson',
#  'tag friend seem count friend',
#  'got mail panren paru',
#  'know lt gt around 5',
#  'sunshin hol claim ur med holiday send stamp self address envelop drink us uk po box 113 bray wicklow eir quiz start saturday unsub stop',
#  'watch tv got new job',
#  '1 new voicemail pleas call 08719181503',
#  'pen thing beyond joke wont biro don master ever',
#  'let snow let snow kind weather bring ppl togeth friendship grow',
#  'no prob hon u doinat mo',
#  'read no shame tell take run blame u 4 ever not realli 4 ever long time',
#  'goodmorn today late lt decim gt min',
#  'alreadi sabarish ask go',
#  'jamster get free wallpap text heart 88888 c appli 16 need help call 08701213186',
#  'guy browsin compulsori',
#  'come aliv better correct good look figur',
#  'say good sign well know track record read women',
#  'privat 2003 account statement show 800 un redeem point call 08715203694 identifi code 40533 expir 31 10 04',
#  'hey babe friend cancel still visit',
#  'hope good week check',
#  'wait still not clear not sure sarcast x doesn want live us',
#  'ok ok ok what ur today plan',
#  'lol pleas actual send pic right wanna see pose comb hair dryer someth',
#  'call get chanc plz lt 3',
#  'k roommat also want dubsack anoth friend may also want plan bring extra tell know sure',
#  'good let thank god pleas complet drug lot water beauti day',
#  'didnt get ur full msg sometext miss send',
#  'honey boo miss u',
#  'r e meet tmr',
#  'happi new year princess',
#  '1 go write msg 2 put dictionari mode 3 cover screen hand 4 press lt gt 5 gentli remov ur hand interest',
#  'shall ask one thing dont mistak',
#  'doubl min doubl txt 1 2 price linerent latest orang bluetooth mobil call mobileupd8 latest offer 08000839402 call2optout lf56',
#  'slept time',
#  'still tonight',
#  'ola would get back mayb not today told direct link us get car bid onlin arrang ship get cut u partnership u invest money ship take care rest u wud b self reliant soon dnt worri',
#  'yep like pink furnitur tho',
#  'trust even isn',
#  'sorri hurt',
#  'tri neva mate',
#  'nah dub je still buff',
#  'cool ta luv v tire 2 caus doin load plan wk got social servic inspect nurseri take care spk sn x',
#  'goodmorn today late 1hr',
#  'tire special',
#  'ye princess want make happi',
#  'kay sinc alreadi',
#  'wnt buy bmw car urgent vri urgent hv shortag lt gt lac no sourc arng di amt lt gt lac that prob',
#  'nice day today love dearli',
#  'don know msg recent',
#  'k k month kote birthday know',
#  'win 200 shop spree everi week start 2 play text store 88039 skilgm tscs08714740323 1winawk age16 1 50perweeksub',
#  'get readi lt gt inch pleasur',
#  'imagin life without see fast u search don worri l alway disturb u goodnoon',
#  'still come tonight',
#  'gonna ring weekend wot',
#  'oop shower u call hey park garag collaps univers hospit see not crazi stuff like happen',
#  'ur go 2 bahama callfreefon 08081560665 speak live oper claim either bahama cruis 2000 cash 18 opt txt x 07786200117',
#  'hi babi im sat bloodi bu mo wont home 7 30 wanna somethin later call later ortxt back jess xx',
#  'practis curtsey',
#  'say slowli god love amp need clean heart blood send ten special peopl amp u c miracl tomorrow pl pl',
#  'hen night go swing',
#  'also bring galileo dobbi',
#  'eye philosophi',
#  'ok cool see ya',
#  'sorri man stash ran dri last night pick sunday',
#  'ok least armand still around',
#  'haf msn yiju hotmail com',
#  'gr8 poli tone 4 mob direct 2u rpli poli titl 8007 eg poli breathe1 titl crazyin sleepingwith finest ymca getz co uk pobox365o4w45wq 300p',
#  'aiyo pleas got time meh',
#  'sent jd custom servic cum account execut ur mail id detail contact us',
#  'day class no class',
#  'went fast asleep dear take care',
#  'dun cut short leh u dun like ah fail quit sad',
#  'beliv come home',
#  'sorri help',
#  'lot use one babe model doesn help youi bring match',
#  'dont make ne plan nxt wknd coz want us come ok',
#  'sorri call later',
#  'suck go u hair free right',
#  'ok no wahala rememb friend need',
#  'ugh gotta drive back sd la butt sore',
#  'go take bath ill place key window',
#  'k go sleep well take rest',
#  'text way cup stop work bu',
#  'today sorri day ever angri ever misbehav hurt plz plz slap urself bcoz ur fault basic good',
#  'juz havent woke bit blur blur dad went liao cant cum oso',
#  'alright took morphin back yo',
#  '4 costa del sol holiday 5000 await collect call 09050090044 toclaim sae tc pobox334 stockport sk38xh cost 1 50 pm max10min',
#  ...]

# %%
X_test
# Out:
# ['squeeeeez christma hug u lik frndshp den hug back u get 3 u r cute 6 u r luvd 9 u r lucki none peopl hate u',
#  'also sorta blown coupl time recent id rather not text blue look weed',
#  'mmm that better got roast b better drink 2 good indian',
#  'mm kanji dont eat anyth heavi ok',
#  'ring come guy costum gift futur yowif hint hint',
#  'sari need tim bollox hurt lot tol',
#  'love isn decis feel could decid love life would much simpler less magic',
#  'supervisor find 4 one lor thk student havent ask yet tell u aft ask',
#  'dear good morn',
#  'chennai velacheri',
#  'lol grr mom take forev prescript pharmaci like 2 minut away ugh',
#  'no valentin huh proof fb page ugh glad realli didn watch rupaul show tool',
#  'wif buy tix lar',
#  'er hello thing didn quit go plan limp slowli home follow aa exhaust hang',
#  'free rington text first 87131 poli text get 87131 true tone help 0845 2814032 16 1st free tone 3x 150pw e nd txt stop',
#  'sir wait call',
#  'crazi ar marri like gd look guy not fren like say korean leona fave dun thk aft think mayb prob go',
#  'hey free call',
#  'fight world easi u either win lose bt fightng some1 close u dificult u lose u lose u win u still lose',
#  'u go back urself lor',
#  'yeah leav coupl minut amp let know get mu',
#  'custom place call',
#  'err cud go 8pm haven got way contact',
#  'guess worri must know way bodi repair quit sure worri take slow first test guid ovul relax noth said reason worri keep followin',
#  '2nd time tri 2 contact u u 750 pound prize 2 claim easi call 087187272008 now1 10p per minut bt nation rate',
#  'k k congratul',
#  'not still look job much ta earn',
#  'gud gud k chikku tke care sleep well gud nyt',
#  'give time walk',
#  'wat',
#  'noth u not dinner w us',
#  'thanx yup come back sun finish dinner go back 2 hotel time fli tog 4 exactli mth today hope haf mani mth come',
#  'xy go 4 e lunch',
#  'pl send compani name saibaba colani',
#  'ur chang 2 da report big co alreadi made chang 2 da previou report',
#  'morn ok',
#  'yeah ju rite',
#  'never lei v lazi got wat dat day send da url cant work one',
#  'aight head',
#  'prefer free day tue wed fri oso ask workin lor',
#  'remind not download content alreadi paid goto http doit mymobi tv collect content',
#  'ju finish blow hair u finish dinner alreadi',
#  'pay like lt gt yr not difficult',
#  'hello boytoy geeee miss today like send tm remind think love love kiss',
#  'aft finish lunch go str lor ard 3 smth lor u finish ur lunch alreadi',
#  'anyth lor',
#  'text creepi like think forgot',
#  'guess somebodi know secretli fanci wanna find give us call 09065394973 landlin datebox1282essexcm61xn 150p min 18',
#  'like jerk',
#  'offic what matter msg call break',
#  'best watch say caus get drunk motherfuck',
#  '8007 free 1st week no1 nokia tone 4 ur mob everi week txt nokia 8007 get txting tell ur mate www getz co uk pobox 36504 w4 5wq norm 150p tone 16',
#  'hey da cool iknow 2 wellda peril studentfinanci crisi spk 2 u l8r',
#  'nah help never iphon',
#  'ok',
#  'even friend priest call',
#  'oh gei happend tron mayb ill dl 3d',
#  'see miss call dear brother gr8 day',
#  'free day finish 6 mon n thur',
#  'good even sir hope nice day want bring notic late pay rent past month pay lt gt charg felt would inconsider nag someth give great cost didnt speak howev recess wont abl pay charg month henc askin well ahead month end pleas help thank everyth',
#  'urgent mobil number award 2000 prize guarante call 09061790121 land line claim 3030 valid 12hr 150ppm',
#  'wat time r go xin hostel',
#  'messag free welcom new improv sex dog club unsubscrib servic repli stop msg 150p 18',
#  'hi hope u get txt journey hasnt gd 50 min late think',
#  'bill letter expect one orang isn bill may still say orang',
#  'annoy isn',
#  'went project centr',
#  'roger probabl go rem 20',
#  'lol don know awesom phone could click delet right want',
#  'height oh shit situat guy throw luv letter gal fall brother head who gay',
#  'sm servic inclus text credit pl goto www comuk net login 3qxj9 unsubscrib stop no extra charg help 08702840625 comuk 220 cm2 9ae',
#  'made day great day',
#  'mobil custom may claim free camera phone upgrad pay go sim card loyalti call 0845 021 3680 offer end 28thfeb c appli',
#  'today voda number end 5226 select receiv 350 award hava match pleas call 08712300220 quot claim code 1131 standard rate app',
#  'oh god found number glad text back xafter msg cst std ntwk chg 1 50',
#  'winner valu network custom select receivea 900 prize reward claim call 09061701461 claim code kl341 valid 12 hour',
#  'still around look pick later',
#  'neft transact refer number lt gt rs lt decim gt credit beneficiari account lt gt lt time gt lt gt',
#  'ok take ur time n enjoy ur dinner',
#  'hey cuti goe wale kinda ok like hill shit still avent kill',
#  'thank love rock',
#  'reach alreadi',
#  'home',
#  'also piec',
#  'next amaz xxx picsfree1 video sent enjoy one vid not enough 2day text back keyword picsfree1 get next video',
#  'quit ok bit ex u better go eat smth els feel guilti',
#  'dude got haircut breezi',
#  'actual fuck whatev find excus tampa point januari though',
#  'no manag puzzel',
#  'hey what plan sat',
#  'fear faint housework quick cuppa',
#  'oh ho first time u use type word',
#  'aiyar u poor thing give u support k jia think u',
#  'got fujitsu ibm hp toshiba got lot model say',
#  'prepar pound everi night',
#  'yeah like goe like friend imma flip shit like half hour',
#  'wow healthi old airport rd lor cant thk anyth els b bath dog later',
#  'dai lt gt naal eruku',
#  'ask around not lot term mid',
#  'u reckon need 2 arrang transport u thank',
#  'ye fine',
#  'wait 4 insid da car park',
#  'dear got train seat mine lower seat',
#  'th gower mate r u man good wale ill b back morrow c u wk msg 4 random',
#  'edison rightli said fool ask question wise man answer know us speechless viva gm gn ge gnt',
#  'r u still work',
#  'yeah sure thing mate haunt got stuff sort im go sound anyway promot hex way dont know number joke',
#  'amaz quot sometim life difficult decid what wrong lie bring smile truth bring tear',
#  'ok ok ok what ur today plan',
#  'sleep nt feel well',
#  'hiya comin 2 bristol 1 st week april le got rudi new yr eve snore drunk u bak colleg yet work send ink 2 bath',
#  'go write ccna exam week',
#  'well might not come',
#  'dear shall mail tonit busi street shall updat tonit thing look ok varunnathu edukkukaye raksha ollu good one real sens',
#  'height confid aeronaut professor wer calld amp wer askd 2 sit aeroplan aftr sat wer told dat plane ws made student dey hurri plane bt 1 didnt move said made student wont even start datz confid',
#  'decemb mobil 11mth entitl updat latest colour camera mobil free call mobil updat co free 08002986906',
#  'account refil success inr lt decim gt keralacircl prepaid account balanc rs lt decim gt transact id kr lt gt',
#  'oh half hour much longer syria canada eh wow must get much work done day us extra time grin',
#  'lmao take pic send',
#  'rock yr chik get 100 filthi film xxx pic yr phone rpli filth 69669 saristar ltd e14 9yt 08701752560 450p per 5 day stop2 cancel',
#  'watch live',
#  'sir need velusami sir date birth compani bank facil detail',
#  'anyth lar',
#  'cool text head',
#  'know thinkin malaria relax children cant handl malaria would wors gastroenter take enough replac loss temp reduc give malaria med vomit self limit ill mean day complet stop',
#  'yo chad gymnast class wanna take site say christian class full',
#  'sure get acknowledg astoundingli tactless gener faggi demand blood oath fo',
#  'hi test lt gt rd',
#  'hous maid murder coz man murder lt gt th januari public holiday govt instituit close includ post offic',
#  'sm auction brand new nokia 7250 4 auction today auction free 2 join take part txt nokia 86021',
#  'yeah usual guy town definit peopl around know',
#  'babe miiiiiiissssssssss need crave geeee sad without babe love',
#  'happi new year no 1 man',
#  'hey thk juz go accordin wat discuss yest lor except no kb sun co nt much lesson go attend kb sat',
#  'take half day leav bec not well',
#  'mayb fat finger press button doesn know',
#  'babe goe day miss alreadi love love kiss hope everyth goe well',
#  'black shirt n blue jean thk c',
#  'gudnit tc practic go',
#  'no worri hope photo shoot went well spif fun workag',
#  'nt drive even mani reason call bbd tht chikku hw abt dvg cold heard tht vinobanagar violenc hw condit hw ru problem',
#  'mom want know',
#  'good good job like entrepreneur',
#  'got tv 2 watch meh u no work today',
#  'pl pl send mail know rel come deliv know cost risk benefit anyth els thank',
#  'might want pull case plan not spend don much confid derek taylor money manag',
#  'privat 2004 account statement 078498 7 show 786 unredeem bonu point claim call 08719180219 identifi code 45239 expir 06 05 05',
#  'sad puppi nois',
#  '4 oclock mine bash flat plan',
#  'not watch movi alreadi xy want 2 shop shop w',
#  'that cool princess cover face hot sticki cum',
#  'unfortun found pick sister airport even don think go tri go one th',
#  'beauti tomorrow never come come alreadi today hunt beauti tomorrow don wast wonder today goodmorn',
#  'pussi perfect',
#  'no medic mission nigeria',
#  'wot wed nite 3 til 9',
#  'number u live 11',
#  'yeah impress got',
#  'hi darlin finish 3 u 1 2 pick meet text back number luv kate xxx',
#  'eldest know',
#  'babe u want dont u babi im nasti thing 4 filthyguy fanci rude time sexi bitch go slo n hard txt xxx slo 4msg',
#  'caus old live high',
#  'no da vijay go talk jaya tv',
#  'don anybodi number still haven thought tact way ask alex',
#  'sorri abl get see morn',
#  'ok take care umma',
#  'want cock hubbi away need real man 2 satisfi txt wife 89938 no string action txt stop 2 end txt rec 1 50ea otbox 731 la1 7w',
#  'xxxmobilemovieclub use credit click wap link next txt messag click http wap xxxmobilemovieclub com n qjkgighjjgcbl',
#  'help u swoop pick u wherev ur bird r meet u want',
#  'peopl tour thought sofa thing sent curiou sugar',
#  'no join today',
#  'come lt 25 n pass lar',
#  'readi call',
#  'no da happi sit togeth na',
#  'wa u effici gee thanx',
#  'short cute good person dont tri prove gud mrng',
#  'no idea guess work hour suppos leav sinc usual nobodi interest figur shit last second',
#  'hello love goe day wish well fine babe hope find job prospect miss boytoy teas kiss',
#  'im late tellmiss im way',
#  'yup next stop',
#  'dont thnk wrong call us',
#  'hey loverboy love tell look pictur ach feel leg fuck want need crave',
#  'love aathi love u lot',
#  'im done studyn librari',
#  'oh howda gud gud math en samachara chikku',
#  'send ur birthdat month year tel u ur life partner name method calcul repli must',
#  'good even',
#  'mani time lose best one bcoz',
#  'hi frnd best way avoid missunderstd wit belov one',
#  'happi new year melodi',
#  'jay say doubl faggot',
#  'pick rayan macleran',
#  'that go ruin thesi',
#  'meet lobbi',
#  'hello go villag pub 8 either come accordingli ok',
#  'ok wont call disturb one know avoid burden',
#  'oh icic k lor den meet day',
#  'sir late pay rent past month pay lt gt charg felt would inconsider nag someth give great cost didnt speak howev recess wont abl pay charg month henc askin well ahead month end pleas help thank',
#  'dai download exe file run exe instal',
#  'sorri call later',
#  'night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay gud mrng',
#  'posibl dnt live lt gt centuri cm frwd n thnk differ',
#  'think rule tamilnadu tough peopl',
#  'sorri brah finish last exam',
#  'know wot peopl wear shirt jumper hat belt know r cribb',
#  'ok ok guess',
#  'sorri call later',
#  'talk',
#  'free entri 250 weekli competit text word win 80086 18 c www txttowin co uk',
#  'wors use half way stop better complet',
#  'somebodi go andro steal ice',
#  'urgent pleas call 09061213237 landlin 5000 cash 4 holiday await collect cs sae po box 177 m227xi 16',
#  'u noe 2 send file 2 comput',
#  'hmm well night night',
#  'final came fix ceil',
#  'affidavit say lt gt e twigg st divis g courtroom lt gt lt time gt doubl check text tomorrow',
#  'go bath msg next lt gt min',
#  'wait come lt gt min',
#  'al moan n e thin goe wrong fault al de argument r fault fed himso bother hav 2go thanx xx',
#  'someth u ate',
#  'wake gt',
#  'congratul thank good friend u 2 000 xma prize 2 claim easi call 08718726971 10p per minut bt nation rate',
#  'work ah den 6 plu lor u workin oso rite den go orchard lor no place go liao',
#  'so amount get pl',
#  'walk hour 2 c u doesn show care wont u believ im seriou',
#  'reason team budget avail last buy unsold player base rate',
#  'dont file bag work call tell find anyth room',
#  'dear call tmorrow pl accomod',
#  'go ride bike',
#  'pl speak wont ask anyth friendship',
#  'sorri call later',
#  'k k also fine complet cours',
#  'k ill drink pa need sr model pl send mail id pa',
#  'get chicken broth want ramen unless don know',
#  'hello darl today would love chat dont tell look like sexi',
#  'unless situat go gurl would appropri',
#  'freemsg txt call no 86888 claim reward 3 hour talk time use phone subscribe6gbp mnth inc 3hr 16 stop txtstop',
#  'well weather cali great complex great need car move freeli tax outrag great place sad part miss home',
#  'urgent tri contact u today draw show 800 prize guarante call 09050001808 land line claim m95 valid12hr',
#  'tire argu week week want',
#  'congrat 2 mobil 3g videophon r call 09063458130 videochat wid ur mate play java game dload polyph music nolin rentl bx420 ip4 5we 150p',
#  'yo parent gettin cash good news pick downstem',
#  'parti alex nichol',
#  'camera award sipix digit camera call 09061221066 fromm landlin deliveri within 28 day',
#  'usual u call ard 10 smth',
#  'nope not drivin neva develop da photo lei',
#  'hungri',
#  'fine send greet',
#  'havent shop lor juz arriv',
#  'ill lt gt ok',
#  'good morn repair shop reason hour',
#  'urgent tri contact last weekend draw show 900 prize guarante call 09061701939 claim code s89 valid 12hr',
#  'wet right',
#  'dear angri busi dear',
#  'call didn see facebook huh',
#  'good sleep rhythm person establish rhythm bodi learn use want know',
#  'come get b quit diff guess rite',
#  'noth ju tot u would ask co u ba gua went mt faber yest yest ju went alreadi mah today not go ju call lor',
#  'come friday leav pongal get news work place',
#  'someon contact date servic enter phone fanci find call landlin 09111032124 pobox12n146tf150p',
#  'guess somebodi know secretli fanci wanna find give us call 09065394514 landlin datebox1282essexcm61xn 150p min 18',
#  '1 don number 2 gonna massiv pain ass rather not get involv possibl',
#  '7 lor chang 2 suntec wat time u come',
#  '7 wonder world 7th 6th ur style 5th ur smile 4th ur person 3rd ur natur 2nd ur sm 1st ur love friendship good morn dear',
#  'somewher beneath pale moon light someon think u dream come true goodnit amp sweet dream',
#  'sorri call later meet',
#  'right make appoint right',
#  'love',
#  'dare ask luck sort car',
#  'take care financi problem help',
#  'get dump heap mom decid come low bore',
#  'new year eve ok went parti boyfriend si hey',
#  'realiz 40 year thousand old ladi run around tattoo',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie',
#  'thank tesco quit nice gone speak soon',
#  '645',
#  'r go 4 today meet',
#  'ex wife not abl kid want kid one day',
#  'oh ok didnt know meant yep babi jontin',
#  'sent type food like',
#  'want 2 get laid tonight want real dog locat sent direct 2 ur mob join uk largest dog network bt txting gravel 69888 nt ec2a 31p msg 150p',
#  'dnt worri use ice piec cloth pack also take 2 tablet',
#  'hi darlin hope nice night wish come cant wait see love fran ps want dirti anal sex want 10 man gang bang',
#  'cuz ibor don wanna studi',
#  'adult would learn experi no real danger dont like peep use drug dont need no comment',
#  'ok c',
#  'hi u decid wot 2 get 4 bday not ill prob ju get voucher frm virgin sumf',
#  'fantasi footbal back tv go sky gamestar sky activ play 250k dream team score start saturday regist sky opt 88088',
#  'today not workin not free oso gee thgt u workin ur fren shop',
#  'slaaaaav must summon time don wish come anymor',
#  'im gonna miss u much',
#  'ur tonex subscript renew charg 4 50 choos 10 poli month www clubz co uk bill msg',
#  'not heard u4 call 4 rude chat privat line 01223585334 cum wan 2c pic gettin shag text pix 8552 2end send stop 8552 sam xxx',
#  'av new number wil u use one ta',
#  'wat r u',
#  'dude ive see lotta corvett late',
#  'promis take good care princess run pleas send pic get chanc ttyl',
#  'sppok ur mob halloween collect nokia logo pic messag plu free eeri tone txt card spook 8007',
#  'wonder would okay call uncl john let know thing not nigeria r lt gt dollar 2year sent know strain plan pay back everi dime give everi dime expect anyth not practic someth like',
#  'urgent mobil no award 2000 bonu caller prize 5 9 03 final tri contact u call landlin 09064019788 box42wr29c 150ppm',
#  'would great guild could meet bristol road somewher get touch weekend plan take flight good week',
#  'master buy bb co sale bf',
#  'lul im gettin juici gossip hospit two nurs talk fat gettin one think she obes oyea',
#  'actual delet old websit blog magicalsong blogspot com',
#  'castor need see someth',
#  'thought king hill thing',
#  'ya srsli better yi tho',
#  'call germani 1 penc per minut call fix line via access number 0844 861 85 85 no prepay direct access',
#  'superb thought grate u dont everyth u want mean u still opportun happier tomorrow u today',
#  'sat right okay thank',
#  'alway chat fact need money rais',
#  'hey sweet wonder moment might come want send file someon go yahoo connect suck rememb set page go download format disc could tell know way download big file download stuff directli internet help would great prey teas kiss',
#  'necessarili respect',
#  'moji love word rich day',
#  'thank rington order refer number x49 mobil charg 4 50 tone not arriv pleas call custom servic 09065989182',
#  'think steyn sure get one wicket',
#  'phone weirdest auto correct',
#  'got wat buy tell us no need come',
#  'cours make stink',
#  'oh god almost home',
#  'no home work meh',
#  'hey congrat 2u2 id luv 2 ive 2 go home',
#  'late',
#  'dude u knw also telugu tht gud k gud nyt',
#  'bloomberg messag center 447797706009 wait appli futur http career bloomberg com',
#  'ok tri week end cours coimbator',
#  'u 447801259231 secret admir look 2 make contact u find r reveal think ur special call 09058094597',
#  'lil fever fine',
#  'say quit least5tim day wudn take much notic nah didn mind gonna see want come taunton tonight u tell',
#  'like person size',
#  'lara said loan lt gt',
#  'water log desert geoenvironment implic',
#  'want insid everi night',
#  'argh fuck nobodi town',
#  'tri make anoth butt',
#  'ugh fuck resub eve',
#  'come peopl',
#  'funni fact nobodi teach volcano 2 erupt tsunami 2 aris hurrican 2 sway aroundn no 1 teach hw 2 choos wife natur disast happen',
#  'well done 4 costa del sol holiday 5000 await collect call 09050090044 toclaim sae tc pobox334 stockport sk38xh cost 1 50 pm max10min',
#  'fuck cedar key fuck come anyway tho',
#  'see swing bit got thing take care firsg',
#  'r u scratch',
#  'start dont stop pray good idea anyth see help guy forward link',
#  'join today formal pl keep pray talk later',
#  '400 xma reward wait comput randomli pick loyal mobil custom receiv 400 reward call 09066380611',
#  'gr8 see messag r u leav congrat dear school wat r ur plan',
#  'omg want scream weigh lost weight woohoo',
#  'yo dude guess got arrest day',
#  'dunno co v late n reach insid alreadi ate spageddi lor e gal r laugh lor',
#  'like new hous',
#  'haha kid papa need drug',
#  'aight yo dat straight dogg',
#  'mum hope great day hope text meet well full life great day abiola',
#  'lost 10 kilo today',
#  'oh god taken teeth pain',
#  'kalli wont bat 2nd inning',
#  'princess bet brotha chase',
#  'import custom servic announc call freephon 0800 542 0825',
#  'actual decid hungri haven left yet v',
#  'pleas inform applic airtel broadband process success instal happen within 3 day',
#  'si como no listened2th plaid album quit gd new air1 hilari also bought braindanc comp ofstuff aphex abel u hav2hear c u sn xxxx',
#  'omg not one thing anoth cat worm bad day end',
#  'said right giggl saw u would possibl first person2di nvq think much could',
#  'ok come ur home half hour',
#  'seem like weird time night g want come smoke day shitstorm attribut alway come make everyon smoke',
#  'fr ndship like needl clock though v r clock v r nt abl 2 met evn v meet itz 4few second bt v alwi stay conect gud 9t',
#  'k k detail want transfer acc no enough',
#  'aldrin rakhesh ex rtm pl call urgent',
#  'unbeliev faglord',
#  'plan usual stop find hella weed smoke hella weed',
#  'still look car buy not gone 4the drive test yet',
#  'common hearin r u wat r u ur day let ask u someth differ u smile today not gud evng',
#  'want send someth sell fast lt gt k not easi money',
#  'also tell said happi birthday',
#  'yup not studi surf lor e lazi mode today',
#  'oh ho first time u use type word',
#  'aight hit get cash',
#  'need go get',
#  'ahhh work vagu rememb feel like lol',
#  '545 lor ya go 4 dinner togeth',
#  'new deu ex game comin earli next yr',
#  'mark take forev pick prescript pain come back',
#  'regist sinco paye log icicibank com enter urn lt gt confirm bewar fraud not share disclos urn anyon',
#  'new theori argument win situat lose person dont argu ur friend kick amp say alway correct',
#  'u fix teeth not asap ok take care',
#  'day ask anand number',
#  'eat old airport road 630 oredi got lot pple',
#  'size eleph tablet u shove um ur ass',
#  'reach home safe n sound liao',
#  'god love no limit god grace no measur god power no boundari may u god endless bless alway ur life gud ni8',
#  'thank look realli appreci',
#  'buy one egg da pleas',
#  'ok lor',
#  'chanc win free bluetooth headset simpli repli back adp',
#  'mu tri figur much money everyon ga alcohol jay tri figur weed budget',
#  'text banneduk 89555 see cost 150p textoper g696ga 18 xxx',
#  'ok way railway',
#  'serious tell exact word right',
#  'rightio 11 48 well arent bright earli morn',
#  'sure drive reach destin soon',
#  'hi kate even hope see tomorrow bit bloodi babyjontet txt back u xxx',
#  'like di sweater fr mango no size alreadi irrit',
#  'get readi put excel sub face',
#  'kind miss train co asthma attack nxt one half hr drive not sure park',
#  'differ style',
#  '2nd attempt contract u week top prize either 1000 cash 200 prize call 09066361921',
#  'blank blank wat blank lol',
#  'no not not movi laptop',
#  'tddnewslett emc1 co uk game thedailydraw dear helen dozen free game great prizeswith',
#  'haven decid yet eh',
#  'not yet chikku k wat abt tht guy stop irrit msging u',
#  'releas vday shirt u put make bottom half nake instead white underwear',
#  'expect whenev text hope goe well tomo',
#  'not cough noth',
#  'rofl betta invest anti age product',
#  'sound great im go sleep good night',
#  'hope thing went well doctor remind still need 2go u c littl thing left loung',
#  'fine difficulti phone work mine pl send anoth friend request',
#  'babe answer see mayb better reboot ym got photo great',
#  'nimbomson yep phone know one obvious co that real word',
#  'know dat feelin pete wuld get em nuther place nuther time mayb',
#  'k must book not huh go yoga basic sunday',
#  'cp caus outag conserv energi',
#  'discuss mother ah',
#  'love aathi love u lot',
#  'great send account number',
#  'urgent ur 500 guarante award still unclaim call 09066368327 closingdate04 09 02 claimcod m39m51 1 50pmmorefrommobile2bremov mobypobox734ls27yf',
#  'u ever get song stuck head no reason go away til u listen like 5 time',
#  'check wid corect spele e sarcasm',
#  'urgent import inform 02 user today lucki day 2 find log onto http www urawinn com fantast surpris await',
#  'oop 4 got bit',
#  'hello boytoy geeee miss alreadi woke wish bed cuddl love',
#  'met alex nichol middl school turn deal',
#  'time prob 3',
#  'u drive lor',
#  'ok shall talk',
#  'u secret admir look 2 make contact u find r reveal think ur special call 09058094565',
#  'naughti littl thought better flirt flirt n flirt rather love someon n gettin hurt hurt n hurt gud nyt',
#  'haha good hear offici paid market 8th',
#  'leav hous',
#  'valu custom pleas advis follow recent review mob no award 1500 bonu prize call 09066364589',
#  'felt not convey reason ese',
#  'u don rememb old commerci',
#  'chang e one next escal',
#  'updat xma offer latest motorola sonyericsson nokia free bluetooth doubl min 1000 txt orang call mobileupd8 08000839402 call2optout f4q',
#  'k wen ur free come home also tel vikki hav sent mail also better come even il free today aftr 6pm',
#  'great attract brotha',
#  'yay final lol miss cinema trip last week',
#  'dunno u ask',
#  'wyli tampa sarasota',
#  'ok thanx',
#  'tell u 2 call 09066358152 claim 5000 prize u 2 enter ur mobil person detail prompt care',
#  'dun believ u thk u told',
#  'got ga money chanc gang want go grand natur adventur',
#  'hi 2night ur lucki night uve invit 2 xchat uk wildest chat txt chat 86688 150p msgrcvdhg suite342 2land row w1j6hl ldn 18yr',
#  'exhaust train morn much wine pie sleep well',
#  'one day train',
#  'gonna ask lol think 7',
#  'didn hear',
#  'leav',
#  'hex place talk explain',
#  'take part mobil survey yesterday 500 text 2 use howev wish 2 get txt send txt 80160 c www txt43 com 1 50p',
#  'rather promin bite mark right cheek',
#  'hey darlin pick u colleg u tell wen 2 mt love pete xx',
#  'surf onlin store offer want buy thing',
#  'dude avatar 3d imp one point thought actual fli room almost tri hittng one reflex',
#  'wine flow never',
#  'super msg da nalla time',
#  'midnight earliest',
#  'sent like',
#  'win 1000 cash prize prize worth 5000',
#  'well done blimey exercis yeah kinda rememb wot hmm',
#  'ask dad pick lar wan 2 stay 6 meh',
#  'oh charg camera',
#  'love want flood pretti pussi cum',
#  'ugh don wanna get bed warm',
#  'well great weekend',
#  'sun anti sleep medicin',
#  'comin fetch us oredi',
#  'friend u stay fb chat',
#  'take small dose tablet fever',
#  '1 000 cash 2 000 prize claim call09050000327',
#  'sorri call later',
#  'height confid aeronaut professor wer calld amp wer askd 2 sit aeroplan aftr sat wer told dat plane ws made student dey hurri plane bt 1 didnt move said made student wont even start datz confid',
#  'sorri light turn green meant anoth friend want lt gt worth may not around',
#  'jesu armand realli tri tell everybodi find',
#  'nah straight bring bud drink someth actual littl use straight cash',
#  'no one interest may busi plan',
#  'sound like mani talent would like go dinner date next week',
#  '2nd time tri contact u u 1450 prize claim call 09053750005 b4 310303 cs stop sm 08718725756 140ppm',
#  'lol oop sorri fun',
#  'messag text miss sender name miss number miss sent date miss miss u lot that everyth miss sent via fullonsm com',
#  'sorri man account dri would want could trade back half could buy shit credit card',
#  'see film',
#  'no 1 polyphon tone 4 ur mob everi week txt pt2 87575 1st tone free get txtin tell ur friend 150p tone 16 repli hl 4info',
#  'seen back holbi',
#  'mum not go robinson alreadi',
#  'okmail dear dave final notic collect 4 tenerif holiday 5000 cash award call 09061743806 landlin tc sae box326 cw25wx 150ppm',
#  'lol well qualiti aint bad aint complain',
#  'noe da car later c lar wear short',
#  'wish u mani mani return day happi birthday vikki',
#  'hate call didnt accept even singl call mine even messag',
#  'u better go sleep dun disturb u liao u wake msg lor',
#  'take like noon',
#  'anyth lor',
#  'send ur friend receiv someth ur voic speak express 1 childish 2 naughti 3 sentiment 4 rowdi 5 ful attitud 6 romant 7 shi 8 attract 9 funni lt gt irrit lt gt lovabl repli',
#  'anyth special',
#  'hi email address chang',
#  'watch tv got new job',
#  'meh thgt clash realli ah dun mind dun seen lost weight gee',
#  'k k cant come search job',
#  'v fan',
#  'mm feel sleepi today shall get dear',
#  'ranjith cal drpd deeraj deepak 5min hold',
#  'think tantrum finish yeah point',
#  'much would cost hire hitman',
#  'no problem spend lot qualiti time togeth',
#  'gentl princess make sweet gentl love',
#  'u meet ur dream partner soon ur career 2 flyng start 2 find free txt horo follow ur star sign e g horo ari',
#  'u secret admir look 2 make contact u find r reveal think ur special call 09065171142 stopsm 08718727870150ppm',
#  'home also',
#  'alreadi squat new way walk',
#  'know dad back',
#  'meet lunch la',
#  'k wait chikku il send aftr lt gt min',
#  'sorri no got thing may pub later',
#  'done oredi',
#  'great hope use connect mode men also co never know old friend lead today',
#  'ga station like block away hous drive right sinc armenia end swann take howard',
#  'haf u found feel stupid da v cam work',
#  'link pictur sent also use http alto18 co uk wave wave asp 44345',
#  'mmmm cant wait lick',
#  'never blame day ur life good day give u happi bad day give u experi essenti life god bless good morn',
#  'actual exam harder nbme',
#  'cant believ said mani thing morn realli want say good morn love beauti morn see librari later',
#  'look fri pan case cheap book perhap no silli fri pan isn like book',
#  'reach home tire come tomorro',
#  'plan pongal',
#  'oh k come tomorrow',
#  'privat 2003 account statement show 800 un redeem point call 08718738001 identifi code 49557 expir 26 11 04',
#  'hi kate u give ring asap xxx',
#  '22 day kick euro2004 u kept date latest news result daili remov send get txt stop 83222',
#  'xma stori peac xma msg love xma miracl jesu hav bless month ahead amp wish u merri xma',
#  'call 09094100151 use ur min call cast 10p min mob vari servic provid aom gbp5 month aom box61 m60 1er u stop age 18',
#  'urgent pleas call 09061743811 landlin abta complimentari 4 tenerif holiday 5000 cash await collect sae cs box 326 cw25wx 150ppm',
#  'lastest stereophon marley dizze racal libertin stroke win nookii game flirt click themob wap bookmark text wap 82468',
#  'true dear sat pray even felt sm time',
#  'get ticket 4 walsal tue 6 th march mate get sat ill pay treat want 2 go txt bak terri',
#  'no messag no responc happend',
#  'u got person stori',
#  'bloomberg messag center 447797706009 wait appli futur http career bloomberg com',
#  'free unlimit hardcor porn direct 2 mobil txt porn 69200 get free access 24 hr chrgd 50p per day txt stop 2exit msg free',
#  '123 congratul week competit draw u 1450 prize claim call 09050002311 b4280703 cs stop sm 08718727868 18 150ppm',
#  'heart empti without love mind empti without wisdom eye r empti without dream amp life empti without frnd alwi touch good night amp sweet dream',
#  'alright bring see like lt gt min',
#  'mean websit ye',
#  'ya well fine bbd pooja full pimpl even becom quit black ur rite cold wear sweatter',
#  'way tirupur',
#  'haha better late ever way could swing',
#  'thank lot wish birthday thank make birthday truli memor',
#  'guy get use dumb realiz',
#  'talk sexi make new friend fall love world discreet text date servic text vip 83110 see could meet',
#  'nowaday peopl notixiqu laxinorf opportun bambl entrop ever oblising opt ur book masteriast amplikat fidalf champlaxig think atroci wotz ur opinion junna',
#  'privat 2004 account statement 07742676969 show 786 unredeem bonu point claim call 08719180248 identifi code 45239 expir',
#  'gimm lt gt minut ago',
#  'k sure rel home sm de pl',
#  'lol wtf random btw lunch break',
#  'v skint fanci bevi waz gona go meet othr spoon jst bin watchng planet earth sofa v comfey dont make hav gd night',
#  'complet degre no use join financ',
#  'come round',
#  'sorri went bed earli nightnight',
#  'oh get even u u',
#  'call tell infront call',
#  'whatsup dont u want sleep',
#  'came hostel',
#  'ye appt',
#  'urgent 2nd attempt contact u u 1000call 09071512432 b4 300603t csbcm4235wc1n3xx callcost150ppmmobilesvari max 7 50',
#  'tension ah machi problem',
#  'r home come within 5 min',
#  'text doesnt repli let know log',
#  'sorri delay ye master',
#  'sorri din lock keypad',
#  'huh lei',
#  'k fyi back parent place south tampa might need deal somewher els',
#  'hey time drive fri go evalu fri',
#  'urgent mobil award 1 500 bonu caller prize 27 6 03 final attempt 2 contact u call 08714714011',
#  'wonder phone batteri went dead tell love babe',
#  'want lick pussi',
#  'nope think go monday sorri repli late',
#  'ya even cooki jelli',
#  'glad went well come 11 plenti time clair goe work',
#  'thank pick trash',
#  'one teach ship car',
#  'lt gt g saw day ago guy want sell wifi lt gt 3g lt gt blank',
#  'long sinc scream princess',
#  'no meet librari',
#  'lick everi drop readi use mouth well',
#  'respons one power weapon 2 occupi place other heart alway give respons 2 care 4 u gud night swt dream take care',
#  'eh sorri leh din c ur msg not sad alreadi lar watch tv u still offic',
#  'noth meant money enter account bank remov flat rate someon transfer lt gt account lt gt dollar got remov bank differ charg also differ sure trust 9ja person send account detail co',
#  'right though give space want need realli start becom issu go suggest set definit move still greec mayb readi',
#  'aiyah wait lor u entertain hee',
#  'thnx dude u guy 2nite',
#  'said not matter mind say matter',
#  'lol grin not babe thank think',
#  'plan',
#  'night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay',
#  'haha first person gonna ask',
#  'ta daaaaa home babe still',
#  'wait cornwal hope tonight isn bad well rock night shite anyway go kip good night speak soon',
#  'u subscrib best mobil content servic uk 3 per 10 day send stop 82324 helplin 08706091795',
#  'dear u invit xchat final attempt contact u txt chat 86688',
#  'could not read love answer',
#  'noth get msg di name wit differ no',
#  'got outta class gonna go gym',
#  'hi hope ur day good back walk tabl book half eight let know ur come',
#  'win realli no 1 side long time',
#  'tri contact respons offer new nokia fone camcord hit repli call 08000930705 deliveri',
#  'k might come tonight class let earli',
#  'noooooooo pleas last thing need stress life fair',
#  'lt gt fast approach wish u happi new year happi sankranti happi republ day happi valentin day happi shivratri happi ugadi happi fool day happi may day happi independ day happi friendship mother father teacher children day amp happi birthday 4 u happi ganesh festiv happi dasara happi diwali happi christma lt gt good morn afternoon even night rememberi first wish u raj',
#  'reach sch alreadi',
#  'up 3day also ship compani take 2wk way usp take week get lag may bribe nipost get stuff',
#  'pleas attend phone',
#  'hey mr go sea view coupl gay mean game give bell ya finish',
#  'no point hangin mr not right not makin u happi',
#  'oh phone phone disconnect',
#  'send number give repli tomorrow morn said like ok',
#  'alright tyler got minor crisi home sooner thought asap',
#  'news hassl get weed week andr no money haughaighgtujhyguj',
#  'k eng rock ash',
#  'hurri home u big butt hang last caller u food done starv don ask cook',
#  'thank way lost',
#  '5 2 work time',
#  'hello drivbi 0quit edrunk sorri iff pthi make no senrd dnot no dancc 2 drum n basq ihav fun 2nhite x ro xxxxxxx',
#  'sorri miss call let talk time 07090201529',
#  'sure don mean get made hold weed',
#  'thank honey great day',
#  'don give fli monkey wot think certainli don mind friend mine',
#  'remind hr',
#  'reach anoth 2 stop',
#  'smile right go world wonder smile think crazi keep away grin',
#  'sorri mail',
#  'hack chat get backdoor entri 121 chat room fraction cost repli neo69 call 09050280520 subscrib 25p pm dp bcm box 8027 ldn wc1n3xx',
#  'probabl around mu lot',
#  'wud never mind u dont miss u dont need u wil realli hurt wen u need amp u dont tell take care',
#  'want show world princess europ',
#  '87077 kick new season 2wk free goal news ur mobil txt ur club name 87077 eg villa 87077',
#  'hang brother famili',
#  'yeah no prob last night obvious catch speak soon',
#  'today accept day u accept brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd no rpli mean enemi',
#  'wish famili merri x ma happi new year advanc',
#  'hmv bonu special 500 pound genuin hmv voucher answer 4 easi question play send hmv 86688 info www 100percent real com',
#  'telli no brdget jone',
#  'mummi boy good bad posit neg mummi made wait hmmmm',
#  'right brah see later',
#  'hey compani elama po mudyadhu',
#  'mm not entir sure understood text hey ho weekend',
#  'took hooch walk toaday fell splat graze knee everyth stay home see tomorrow',
#  'sorri pa dont knw ru pa',
#  'think chuckin ur red green n black trainner 2 save carryin bac train',
#  'farm open',
#  'eh u rememb 2 spell name ye v naughti make v wet',
#  'wish thing differ wonder abl show much valu pl continu brisk walk no drug without askin pleas find thing laugh love dearli',
#  'yar lor u noe u use dat rout',
#  'one good partnership go take lead',
#  'oic saw tot din c found group liao',
#  'head dey swell oh thank make day',
#  'see letter b car',
#  'wont touch permiss',
#  'justbeen overa week sinc broke alreadi brain go mush',
#  'fishrman woke earli mrng dark wait amp found sack ful stone strtd throwin thm in2 sea 2 pass time atlast ju 1stone sun rose amp found tht r nt stone diamond moral dont wake earli mrng good night',
#  'later guess needa mcat studi',
#  'pl speak custom machan',
#  'guy',
#  'ladi first genu second k',
#  'still area restaur ill tri come back soon',
#  'boy love gal propsd bt didnt mind gv lv lttr bt frnd threw thm boy decid 2 aproach gal dt time truck speed toward gal wn 2 hit girl boy ran like hell n save ask hw cn u run fast boy repli boost secret energi n instantli girl shout energi n thi live happili 2gthr drink boost evrydi moral stori hv free msg gud ni8',
#  'mobil club choos top qualiti item mobil 7cfca1a',
#  'mani time told stage use laugh not listen aha',
#  'sac need carri',
#  'marri local women look discreet action 5 real match instantli phone text match 69969 msg cost 150p 2 stop txt stop bcmsfwc1n3xx',
#  'think mentor not 100 percent sure',
#  'one day billion class right',
#  'what come hill monster hope great day thing r go fine busi though',
#  'realli hope work doesnt get stress gr8 day',
#  'realli not still tonight babe',
#  'oh yeah clearli fault',
#  'hous maid murder coz man murder lt gt th januari public holiday govt instituit close includ post offic understand',
#  'sure whenev show fuck gt',
#  'multipli number independ count decim point divis push decim place like show',
#  'time fix spell sometim get complet diff word go figur',
#  'suppos meet discuss abt trip thought xuhui told afternoon thought go lesson',
#  'bank say money',
#  'yunni goin late',
#  'know pl open back',
#  'want lt gt rs da',
#  'absolut love south park recent start watch offic',
#  'joy father john john joy father u an th hav lt gt iq ti ia question tri answer',
#  'how favourit person today r u workin hard couldn sleep last nite nearli rang u 4 30',
#  'surpris still guess right lor',
#  'speak feel word better silenc gud mrng',
#  'good morn pooki pie lol hope didn wake u',
#  'wnevr wana fal luv vth book bed fal luv vth yen madodu nav pretsorginta nammanna pretsovru import alwa gud eveb',
#  'chang fb jaykwon thuglyf falconerf',
#  'even u dont get troubl convinc tel twice tel neglect msg dont c read dont repli',
#  'way stay oh',
#  'keep ur problem ur heart b coz nobodi fight u u amp u fight ur self amp win battl vivekanand g 9t sd ham yeah give call got minut ham hi babe uawak feellikw shit justfound via alett thatmum gotmarri 4thnov behind ourback fuckinnic selfish deviousbitch anyway l call u',
#  'hcl chennai requir fresher voic process excel english need salari upto lt gt call ms suman lt gt telephon interview via indyarock com',
#  'couldn say no die man feel sad go want know would probabl gone late night',
#  'ok sweet dream',
#  'cancel cheyyamo get money back',
#  'u still havent got urself jacket ah',
#  'ye rent expens way save',
#  'yup bath liao',
#  'call u done',
#  'k sent',
#  'sure make sure know smokin yet',
#  'great aunt anniversari parti tarpon spring',
#  'want mapquest someth look usf dogwood drive tini street park lot',
#  'hi dear call urgnt don know what problem don want work problem least tell wate repli',
#  'don know account detail ask mom send mom reach',
#  'pleas don text anymor noth els say',
#  'let pool money togeth buy bunch lotto ticket win get lt gt u get lt gt deal',
#  'privat 2003 account statement show 800 un redeem point call 08715203685 identifi code 4xx26 expir 13 10 04',
#  'ok chines food way get fat pay lipo',
#  'imposs argu alway treat like sub like never releas remind necessari',
#  'buzz hey love think hope day goe well sleep miss babe long moment togeth love smile',
#  'sorri earlier put fire around talk 9 actual life lol',
#  'ok good make money',
#  'free video camera phone half price line rental 12 mth 500 cross ntwk min 100 txt call mobileupd8 08001950382 call2optout 674',
#  '400 xma reward wait comput randomli pick loyal mobil custom receiv 400 reward call 09066380611',
#  'ok anoth number',
#  'ye said',
#  'sound like someth someon test would sayi',
#  'know grumpi old peopl mom like better not lie alway one play joke',
#  'got part nottingham 3 hr 63mile good thing love man much 40mph hey ho',
#  'rose need water season need chang poet need imagin phone need ur sm need ur love frndship forev',
#  'ok u take shop u get paid',
#  'good night dear sleepwel amp take care',
#  'meet darren',
#  'believ true incred txt repli g learn truli amaz thing blow mind o2fwd 18p txt',
#  'laptop take',
#  '1 thing chang sentenc want 2 concentr educ career im leav',
#  'still around could use half 8th',
#  'ultim tor motiv tui achiev korli',
#  'hi darlin youphon im athom youwanna chat',
#  'pain person thought alway tri keep everybodi happi time nobodi recognis alon',
#  'guy plan come',
#  'jay want work first 4 sound',
#  'r u cook dinner',
#  'ok da alreadi plan wil pick',
#  'shall start hear',
#  'hard live 121 chat 60p min choos girl connect live call 09094646899 cheap chat uk biggest live servic vu bcm1896wc1n3xx',
#  'cant pick phone right pl send messag',
#  'custom loyalti offer new nokia6650 mobil 10 txtauction txt word start no 81151 get 4t ctxt tc 150p mtmsg',
#  'aight ill get fb coupl minut',
#  'yep fine 7 30 8 30 ice age',
#  'good morn dear shijutta great amp success day',
#  'lol ye friendship hang thread caus u buy stuff',
#  'well littl time thing good time ahead',
#  'li hai bore da lectur repeat last week stuff wast time',
#  'save money wed lingeri www bridal petticoatdream co uk choos superb select nation deliveri brought weddingfriend',
#  'jokin lar depend phone father get lor',
#  'hasn pattern recent crap weekend',
#  'much eighth',
#  'joy father john john name joy father mandan',
#  'hungri buy smth home',
#  'goodmorn grandfath expir leav today',
#  'place man',
#  'wat make peopl dearer not de happi dat u feel u meet de pain u feel u miss dem',
#  'dont know come ask question like dont mistak',
#  'sorri batteri die yeah',
#  'new 2 club dont fink met yet b gr8 2 c u pleas leav msg 2day wiv ur area 09099726553 repli promis carli x call 1 minmobsmor lkpobox177hp51fl',
#  'dnt wnt tlk wid u',
#  'ok',
#  'shall bring us bottl wine keep us amus joke bring one anyway',
#  'final happen aftr decad beer cheaper petrol gover expect us drink don drive',
#  'no shoot doc wait room',
#  'no current scotland',
#  'want new video handset 750 time network min unlimit text camcord repli call 08000930705 del sat',
#  'k make sens btw carlo difficult guy gonna smoke go pick second batch get ga',
#  'pleas call custom servic repres freephon 0808 145 4742 9am 11pm guarante 1000 cash 5000 prize',
#  'great hope like man well endow lt gt inch',
#  'wow boy r back take 2007 uk tour win vip ticket pre book vip club txt club 81303 trackmarqu ltd info vipclub4u',
#  'dunno ju say go lido time 930',
#  'ic lol play 9 door sometim yo',
#  'long applebe fuck take',
#  'sef dey laugh meanwhil darl anji',
#  'toshiba porteg m100 gd',
#  'fine hope also',
#  'yup still coffe wif fren fren drove give lift',
#  'nervou lt gt',
#  'haf u eaten wat time u wan 2 come',
#  'contract mobil 11 mnth latest motorola nokia etc free doubl min text orang tariff text ye callback no remov record',
#  'burger king wanna play footi top stadium get 2 burger king 1st sept go larg super coca cola walk winner',
#  'k delet contact',
#  'tell u headach want use 1 hour sick time',
#  '5 night nt stay port step liao ex',
#  'ask g iouri told stori like ten time alreadi',
#  'donno gene someth',
#  'urgent 1 week free membership 100 000 prize jackpot txt word claim no 81010 c www dbuk net lccltd pobox 4403ldnw1a7rw18',
#  'pleas call custom servic repres 0800 169 6031 10am 9pm guarante 1000 cash 5000 prize',
#  'yeah probabl',
#  'ok gentleman treat digniti respect',
#  'sorri call later',
#  'said kiss kiss sound effect gorgeou man isn kind person need smile brighten day',
#  'yar say got error',
#  'boo way mom make tortilla soup yummmm',
#  'alright make sure car back tonight',
#  'true passabl get high score appli phd get 5year salari make life easier',
#  'honestli made love cup tea promptli drop key burnt finger get',
#  'haha sound crazi dunno tahan anot',
#  'oh k k take test',
#  'got got 2 colour lor one colour quit light n e darker lor actual done style hair',
#  'free 1st week no1 nokia tone 4 ur mobil everi week txt nokia 8077 get txting tell ur mate www getz co uk pobox 36504 w45wq 16 norm150p tone',
#  'ur chanc win 250 wkli shop spree txt shop 80878 c www txt 2 shop com custcar 08715705022 1x150p wk',
#  'congratul thank good friend u 2 000 xma prize 2 claim easi call 08712103738 10p per minut bt nation rate',
#  'put readi lt time gt',
#  'guarante latest nokia phone 40gb ipod mp3 player 500 prize txt word collect no 83355 ibhltd ldnw15h 150p mtmsgrcvd18',
#  'good morn plz call sir',
#  'wait know wesley town bet hella drug',
#  '7 esplanad mind give lift co got no car today',
#  'thank honey still haven heard anyth leav bit longer not 2 crowd tri later great advic thank hope cardiff still',
#  'lol hot air balloon',
#  'come room cannot come hous co hous still messi haha',
#  'k give sec break lt gt cstore',
#  'co shop wif darren ju n call 2 ask wat present wan lor start guess wif n final guess darren lor',
#  'sing hu think also import find someon femal know place well prefer citizen also smart help navig even thing like choos phone plan requir guidanc doubt ask especi girl',
#  'call da wait call',
#  'nokia 7250i get win free auction take part send nokia 86021 hg suite342 2land row w1jhl 16',
#  'tri contact repli offer video handset 750 anytim network min unlimit text camcord repli call 08000930705',
#  'sorri roommat took forev ok come',
#  'daddi shu shu look 4 u u wan 2 tell u not singapor wat',
#  'say haven explicitli told nora know someon probabl not gonna bother',
#  'u sound like manki scous boy steve like travel da bu home wot u inmind 4 recreat di eve',
#  'solihul want anyth',
#  'gud mrng dear hav nice day',
#  'dude like buff wind',
#  'yup wun believ wat u realli neva c e msg sent shuhui',
#  'get gift year didnt get anyth bad',
#  'hello orang 1 month free access game news sport plu 10 free text 20 photo messag repli ye term appli www orang co uk ow',
#  'still attend da talk',
#  'thk em find wtc far weiyi not goin e rest dunno yet r ur goin 4 dinner den might b abl join',
#  'oh send address',
#  'sister law hope great month say hey abiola',
#  'also maaaan miss',
#  'nope still market',
#  'u come back 4 dinner rite dad ask confirm wif u',
#  'ok',
#  'well ball time make call',
#  'ok part tomorrow',
#  'lol no need cash nitro hurri come crash',
#  'except there chick huge boob',
#  'know girl alway safe selfish know got pa thank good night',
#  'schedul next week town weekend',
#  'hi happi birthday hi hi hi hi hi hi hi',
#  'hi msg offic',
#  'k k sister kid',
#  'oh got mani respons',
#  'press confer da',
#  'hi engag fixd lt gt th next month know realli shock bt hmm njan vilikkam ws al sudn',
#  'sunni california weather cool',
#  'dad went oredi',
#  'will go aptitud class',
#  'sir hope day go smoothli realli hope wont bother bill settl month extra cash know challeng time also let know',
#  'said would woke',
#  'haha awesom 4u coupl time come',
#  'tmr timin still da wat co got lesson 6',
#  'shoot big load get readi',
#  'fair enough anyth go',
#  'describ lucki actual awak noon',
#  'hi kindli give us back document submit loan stapati',
#  'love come took long leav zaher got word ym happi see sad left miss',
#  'ey calm downon theacus itxt u co iwana know wotu r doin thew end haventcn u age ring ur up4 neth sat love j xxx',
#  'horribl u eat mac eat u forgot abt alreadi rite u take long 2 repli thk toot b4 b prepar wat shall eat',
#  'anyth specif regard jaklin idk fuck',
#  'live next lt gt min',
#  'take lt gt min',
#  'no no kalli home ground amla home town durban',
#  'tkt euro2004 cup final 800 cash collect call 09058099801 b4190604 pobox 7876150ppm',
#  'ok ok take care understand',
#  'import inform 4 orang user 0789xxxxxxx today lucki day 2find log onto http www urawinn com fantast surpris await',
#  'busi come point figur tomorrow',
#  'hey boy want hot xxx pic sent direct 2 ur phone txt porn 69855 24hr free 50p per day stop text stopbcm sf wc1n3xx',
#  'good afternoon sexi bun goe job search wake first thought alway love wish fine happi know ador',
#  'class hour sorri',
#  'glad see repli',
#  'sorri call later',
#  'not much no fight good nite',
#  'yo guy ever figur much need alcohol jay tri figur much safe spend weed',
#  'superior tell friday leav depart except leav way call wahe fathima hr conform',
#  'probabl earlier station think',
#  'congratul ore mo owo wa enjoy wish mani happi moment fro wherev go',
#  'cours guess god got hold right',
#  'two letter copi co one messag speak soon',
#  'hear loud scream lt gt minut caus gyno shove thing don belong',
#  'kalli readi bat 2nd inning',
#  'type stuff sing',
#  'bugi juz wat walk home oredi late repli oso saw top dat like din buy r',
#  'bring home wendi',
#  'thk shld b ya wana go 4 lesson haha go one whole stretch',
#  'wif famili book tour packag',
#  'ur pin',
#  'good think could send pix would love see top bottom',
#  'want tel u one thing u not mistak k messag sent',
#  '123 congratul week competit draw u 1450 prize claim call 09050002311 b4280703 cs stop sm 08718727868 18 150ppm',
#  'urgent mobil number 2000 bonu caller prize 10 06 03 2nd attempt reach call 09066368753 asap box 97n7qp 150ppm',
#  'contact date servic someon know find call land line 09050000928 pobox45w2tg150p',
#  'super da good replac murali',
#  'teach app da come colleg',
#  'ye dont care need bad princess',
#  'dont thnk wrong call us',
#  'wen ur lovabl bcum angri wid u dnt take serious coz angri childish n true way show deep affect care n luv kettoda manda nice day da',
#  'u earli',
#  'fine miss much',
#  'check realli miss see jeremiah great month',
#  'sorri call later',
#  'stitch trouser',
#  'haha dinner cousin',
#  'much torch 9ja',
#  'look ami ure beauti intellig woman like u lot know u don like like don worri',
#  'christma occas celebr reflect ur valu desir affect amp tradit ideal christma',
#  'dont hesit know second time weak like keep notebook eat day anyth chang day sure noth',
#  'yeah don stand close tho catch someth',
#  'petey boy wherear friendsar thekingshead come canlov nic',
#  'babe love cover face kiss',
#  'privat 2003 account statement 078',
#  'ye mum lookin strong',
#  'lol alway convinc',
#  'shb b ok lor thanx',
#  'wait lt gt min',
#  'happi birthday may u find ur princ charm soon n dun work hard',
#  'watch lotr w si di aft u wan 2 meet 4 dinner nite not',
#  'lift hope offer money need especi end month approach hurt studi anyway gr8 weekend',
#  'hey babe saw came onlin second disappear happen',
#  'no luton 0125698789 ring ur around h',
#  'u sick still go shop',
#  'pain couldn come wors time',
#  'want talk',
#  'privat 2003 account statement show 800 un redeem point call 08715203652 identifi code 42810 expir 29 10 0',
#  'die accident delet e msg suppos 2 put e sim archiv haiz sad',
#  'still get good',
#  'no de see onlin shop ask',
#  'sorri da thought call lot time lil busi call noon',
#  'pl call da happen',
#  'no da stupid da alway send like don believ messag pandi mental',
#  'lmao know well',
#  'that cool like photo sexi',
#  'saw guy doll last night patrick swayz great',
#  'emigr someth ok mayb 5 30 bit hope',
#  'valu vodafon custom comput pick win 150 prize collect easi call 09061743386',
#  'thank princess sexi',
#  'don know u u don know send chat 86688 let find 150p msg rcvd hg suite342 2land row w1j6hl ldn 18 year',
#  'town v import',
#  'strang watch 2nd one bed sweet dream miss u',
#  'tomorrow not go theatr come wherev u call tell come tomorrow',
#  'pl pl find aunt nike',
#  'hot live fantasi call 08707500020 20p per min ntt ltd po box 1327 croydon cr9 5wb 0870 nation rate call',
#  'no call messag miss call',
#  'lol differ don go tri find everi real life photo ever took',
#  'sorri call later',
#  'loosu go hospit de dont let careless',
#  'plane give month end',
#  'play smash bro lt gt religi',
#  'gonna rip uteru',
#  'dont knw pa drink milk',
#  'ok lor',
#  'thought slide enough',
#  'gotta collect da car 6 lei',
#  'r home come within 5 min',
#  'account refil success inr lt decim gt keralacircl prepaid account balanc rs lt decim gt transact id kr lt gt',
#  'yeah sure leav min',
#  'wanna get laid 2nite want real dog locat sent direct ur mobil join uk largest dog network txt park 69696 nyt ec2a 3lp 1 50 msg',
#  'sorri call later',
#  'one regist subscrib u enter draw 4 100 g b gift voucher repli enter unsubscrib text stop',
#  'hey doc pl want get nice shirt hubbi nice fite one budget lt gt k help pl load card abi hw keep post luv 2 mj',
#  'argh 3g spotti anyway thing rememb research provinc sterl problem free place look',
#  'k pick anoth 8th done',
#  'custom place call',
#  'don know wait check',
#  'ha say didn read anyth way u seem don like 2 judgement save friday pub',
#  'b4u voucher w c 27 03 marsm log onto www b4utel com discount credit opt repli stop custom care call 08717168528',
#  'doubl min 1000 txt orang tariff latest motorola sonyericsson nokia bluetooth free call mobileupd8 08000839402 call2optout hf8',
#  'per request maangalyam alaipayuth set callertun caller press 9 copi friend callertun',
#  'rose red red blood blood heart heart u u send ti ur friend includ u like u get back 1 u r poor relat 2 u need 1 support 3 u r frnd 2 mani 4 some1 luv u 5 some1 pray god marri u tri',
#  'free2day sexi st georg day pic jordan txt pic 89080 dont miss everi wk sauci celeb 4 pic c pocketbab co uk 0870241182716 3 wk',
#  'somewher beneath pale moon light someon think u dream come true goodnit amp sweet dream',
#  'great trip india bring light everyon not project everyon lucki see smile bye abiola',
#  'apo mokka player',
#  'staff scienc nu edu sg phyhcmk teach pc1323',
#  'hi probabl much fun get messag thought id txt u co im bore jame fart night',
#  'gonna get rimac access',
#  'ye place town meet excit adult singl uk txt chat 86688 150p msg',
#  'world happiest frnd never charact dey best understand differ',
#  'sm servic inclus text credit pl goto www comuk net login unsubscrib stop no extra charg help 08700469649 po box420 ip4 5we',
#  'love cuddl want hold strong arm right',
#  'oh ya ya rememb da',
#  'ok no prob take ur time',
#  'doubl min doubl txt 1 2 price linerent latest orang bluetooth mobil call mobileupd8 latest offer 08000839402 call2optout lf56',
#  ...]

# %%
y.value_counts()
# Out:
# spam
# 0       4825
# 1        747
# dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500)
X_train = cv.fit_transform(X_train).toarray()

# %%
X_test = cv.transform(X_test).toarray()

# %%
X_test.shape
# Out:
# (1115, 2500)

# %%
cv.vocabulary_
# Out:
# {'repli': 1804,
#  'win': 2416,
#  '100': 43,
#  'weekli': 2387,
#  'world': 2450,
#  'cup': 656,
#  'held': 1023,
#  'send': 1884,
#  'stop': 2082,
#  '87239': 195,
#  'end': 792,
#  'servic': 1893,
#  'hello': 1027,
#  'sort': 2023,
#  'town': 2254,
#  'alreadi': 267,
#  'dont': 750,
#  'rush': 1843,
#  'home': 1057,
#  'eat': 777,
#  'let': 1309,
#  'know': 1258,
#  'come': 588,
#  'go': 958,
#  'tell': 2183,
#  'told': 2237,
#  'hey': 1033,
#  'till': 2226,
#  'dint': 728,
#  'meet': 1449,
#  'not': 1569,
#  'even': 814,
#  'singl': 1949,
#  'time': 2227,
#  'saw': 1858,
#  'situat': 1957,
#  'orang': 1611,
#  'bring': 456,
#  'rington': 1823,
#  'chart': 540,
#  'hero': 1032,
#  'free': 907,
#  'hit': 1041,
#  'week': 2385,
#  'pic': 1662,
#  'wap': 2369,
#  'receiv': 1778,
#  'sit': 1954,
#  'mu': 1520,
#  'wait': 2358,
#  'everyon': 818,
#  'get': 946,
#  'suit': 2111,
#  'take': 2154,
#  'shower': 1929,
#  'finish': 873,
#  'liao': 1311,
#  'urgent': 2312,
#  'mobil': 1487,
#  'no': 1558,
#  'award': 355,
#  '000': 1,
#  'bonu': 431,
#  'caller': 489,
#  'prize': 1723,
#  '02': 2,
#  '03': 4,
#  '2nd': 112,
#  'attempt': 339,
#  'contact': 610,
#  'call': 485,
#  '0871': 30,
#  'box95qu': 446,
#  'probabl': 1725,
#  'still': 2076,
#  'stuff': 2096,
#  'wah': 2356,
#  'lucki': 1388,
#  'man': 1421,
#  'save': 1857,
#  'money': 1498,
#  'hee': 1022,
#  'gym': 991,
#  'oh': 1589,
#  'lk': 1339,
#  'tt': 2271,
#  'den': 708,
#  'one': 1597,
#  'cine': 564,
#  'lor': 1360,
#  'dun': 768,
#  'wan': 2365,
#  'yogasana': 2492,
#  'oso': 1618,
#  'ok': 1590,
#  'havent': 1010,
#  'collect': 582,
#  'pl': 1673,
#  'place': 1674,
#  'sent': 1886,
#  'number': 1576,
#  'stupid': 2097,
#  'possibl': 1699,
#  'secret': 1874,
#  'admir': 230,
#  'reveal': 1817,
#  'think': 2206,
#  'special': 2035,
#  'opt': 1607,
#  '50': 149,
#  'per': 1650,
#  'msg': 1515,
#  'recd': 1776,
#  'cust': 659,
#  'care': 510,
#  '07821230901': 8,
#  'amaz': 273,
#  'letter': 1310,
#  'give': 953,
#  'mean': 1444,
#  'dirti': 731,
#  'room': 1832,
#  'moon': 1503,
#  'eye': 838,
#  'see': 1876,
#  'result': 1814,
#  'lie': 1316,
#  'mother': 1507,
#  'law': 1286,
#  'woman': 2442,
#  'plu': 1681,
#  'two': 2279,
#  'twelv': 2277,
#  'listen': 1334,
#  'live': 1337,
#  'chat': 542,
#  'offic': 1586,
#  'right': 1821,
#  'total': 2249,
#  '60p': 162,
#  'min': 1468,
#  '24': 94,
#  'never': 1547,
#  'want': 2368,
#  'short': 1922,
#  'late': 1281,
#  'wil': 2414,
#  'reach': 1766,
#  'yeah': 2479,
#  'diet': 721,
#  'window': 2417,
#  'shit': 1914,
#  'thought': 2212,
#  'trip': 2262,
#  'make': 1418,
#  'much': 1521,
#  'sens': 1885,
#  'grin': 981,
#  'sofa': 1998,
#  'refer': 1785,
#  'sleep': 1969,
#  'link': 1328,
#  'went': 2394,
#  'didn': 718,
#  'babe': 361,
#  'celebr': 528,
#  'rent': 1800,
#  'greet': 980,
#  'joy': 1213,
#  'happi': 1003,
#  'gr8': 973,
#  'armand': 319,
#  'say': 1859,
#  'ass': 333,
#  'aiyah': 252,
#  'lar': 1278,
#  'don': 748,
#  'watch': 2375,
#  'film': 868,
#  'comput': 598,
#  'heard': 1018,
#  'abt': 212,
#  'tat': 2165,
#  'oop': 1602,
#  'sorri': 2021,
#  'check': 547,
#  'mind': 1469,
#  'pick': 1663,
#  'tomo': 2240,
#  'half': 998,
#  'station': 2068,
#  'would': 2455,
#  'anytim': 297,
#  'friendship': 916,
#  'dear': 687,
#  'near': 1539,
#  'hear': 1017,
#  'cheer': 548,
#  'tear': 2177,
#  'alway': 272,
#  'gud': 987,
#  'ni8': 1552,
#  'yar': 2476,
#  'els': 786,
#  'thk': 2208,
#  'funni': 927,
#  'thing': 2205,
#  'love': 1372,
#  'isn': 1171,
#  'decis': 695,
#  'feel': 859,
#  'could': 621,
#  'decid': 693,
#  'life': 1317,
#  'less': 1307,
#  'magic': 1412,
#  'exact': 822,
#  'intent': 1152,
#  'erm': 806,
#  'somewher': 2010,
#  'everi': 816,
#  'day': 682,
#  'use': 2317,
#  'lt': 1384,
#  'gt': 985,
#  'ju': 1218,
#  'hope': 1064,
#  'true': 2264,
#  'missin': 1477,
#  'co': 576,
#  'realli': 1774,
#  'haven': 1009,
#  'done': 749,
#  'anyth': 295,
#  'yet': 2486,
#  'yup': 2498,
#  'whether': 2401,
#  'cut': 662,
#  'hmv': 1048,
#  '500': 150,
#  'pound': 1702,
#  'voucher': 2349,
#  'answer': 290,
#  'easi': 775,
#  'question': 1747,
#  'play': 1676,
#  '86688': 190,
#  'info': 1139,
#  'www': 2464,
#  '100percent': 45,
#  'real': 1769,
#  'com': 585,
#  'final': 869,
#  'chanc': 535,
#  'claim': 567,
#  'ur': 2309,
#  '150': 65,
#  'worth': 2453,
#  'discount': 732,
#  'today': 2235,
#  'text': 2193,
#  'ye': 2478,
#  '85023': 188,
#  'savamob': 1856,
#  'member': 1453,
#  'offer': 1585,
#  'cs': 650,
#  'pobox84': 1688,
#  'm263uz': 1401,
#  '00': 0,
#  'sub': 2100,
#  '16': 73,
#  'nt': 1573,
#  'boytoy': 449,
#  'mr': 1512,
#  'sheffield': 1906,
#  'wanna': 2367,
#  'game': 933,
#  'okay': 1591,
#  'boss': 438,
#  'rais': 1755,
#  'prepar': 1714,
#  'pleasur': 1679,
#  'abl': 211,
#  'friday': 914,
#  'find': 870,
#  'yr': 2494,
#  'term': 2189,
#  'good': 965,
#  'morn': 1505,
#  'im': 1113,
#  'suffer': 2108,
#  'cash': 517,
#  'balanc': 369,
#  'current': 657,
#  'maxim': 1440,
#  '150p': 67,
#  'cc': 525,
#  '08718720201': 35,
#  'po': 1684,
#  'box': 444,
#  '114': 53,
#  '14': 62,
#  'tcr': 2172,
#  'w1': 2351,
#  'forward': 902,
#  'messag': 1459,
#  'back': 364,
#  'thank': 2198,
#  'confirm': 603,
#  'buy': 474,
#  'date': 680,
#  'cal': 482,
#  'foreign': 895,
#  'stamp': 2060,
#  'whatev': 2397,
#  'haha': 994,
#  'receipt': 1777,
#  'sound': 2026,
#  'gd': 941,
#  'luck': 1387,
#  'chikku': 551,
#  'ya': 2473,
#  'like': 1323,
#  'second': 1873,
#  'cant': 504,
#  'anyon': 294,
#  'spare': 2033,
#  'top': 2246,
#  'head': 1014,
#  'sex': 1897,
#  'sexi': 1898,
#  'jordan': 1211,
#  '88600': 199,
#  'wk': 2430,
#  'uk': 2289,
#  'colleg': 583,
#  'class': 568,
#  'freephon': 910,
#  '0800': 11,
#  '542': 157,
#  'worri': 2451,
#  'march': 1427,
#  'ish': 1169,
#  '88066': 198,
#  'lost': 1363,
#  '12': 56,
#  'help': 1029,
#  'great': 978,
#  'seri': 1889,
#  'birthday': 410,
#  'wish': 2423,
#  'gonna': 964,
#  'normal': 1568,
#  'start': 2065,
#  'tuesday': 2273,
#  'problem': 1726,
#  'renew': 1799,
#  'away': 356,
#  'detail': 714,
#  'bad': 365,
#  'girl': 950,
#  'ladi': 1270,
#  'actual': 224,
#  'guy': 990,
#  'way': 2377,
#  'prolli': 1731,
#  'download': 754,
#  'fring': 917,
#  'app': 303,
#  'machan': 1406,
#  'complet': 596,
#  'form': 900,
#  'also': 270,
#  'utter': 2321,
#  'wast': 2373,
#  'got': 970,
#  'howz': 1077,
#  'pain': 1631,
#  'said': 1848,
#  'ice': 1102,
#  'hmm': 1046,
#  'shall': 1901,
#  'wine': 2418,
#  'keep': 1236,
#  'us': 2316,
#  'joke': 1208,
#  'red': 1782,
#  'white': 2402,
#  'tomorrow': 2241,
#  'takin': 2156,
#  'aww': 358,
#  'first': 875,
#  'miss': 1476,
#  'without': 2428,
#  'ask': 329,
#  'mayb': 1442,
#  'ym': 2489,
#  'seen': 1878,
#  'buzz': 476,
#  'hi': 1035,
#  'darlin': 677,
#  'london': 1352,
#  'smash': 1984,
#  'anoth': 288,
#  'big': 403,
#  'xxx': 2470,
#  'toa': 2233,
#  'payoh': 1645,
#  'return': 1816,
#  'smth': 1991,
#  'wat': 2374,
#  'leav': 1296,
#  'qatar': 1743,
#  'tonit': 2244,
#  'opportun': 1606,
#  'touch': 2250,
#  'email': 789,
#  'kerala': 1240,
#  'lol': 1351,
#  'forgot': 899,
#  'eh': 784,
#  'someon': 2006,
#  'enter': 800,
#  'phone': 1660,
#  'fanci': 845,
#  'landlin': 1273,
#  'mail': 1415,
#  'movi': 1510,
#  'tri': 2261,
#  'last': 1280,
#  'weekend': 2386,
#  'draw': 755,
#  'show': 1928,
#  '900': 203,
#  'guarante': 986,
#  'code': 577,
#  'valid': 2323,
#  'littl': 1336,
#  'rs': 1838,
#  'decim': 694,
#  'credit': 642,
#  'account': 219,
#  'dollar': 747,
#  'ill': 1112,
#  '2mrw': 111,
#  'address': 229,
#  'american': 274,
#  'wont': 2445,
#  'callin': 492,
#  'jen': 1195,
#  'pa': 1626,
#  'self': 1880,
#  'drive': 761,
#  'sch': 1862,
#  'gram': 975,
#  'usual': 2320,
#  'run': 1842,
#  'though': 2211,
#  'almost': 264,
#  'whole': 2405,
#  'quit': 1750,
#  'ex': 821,
#  'bother': 440,
#  'trust': 2266,
#  'men': 1454,
#  'shorter': 1924,
#  'doctor': 741,
#  'tire': 2228,
#  'uni': 2296,
#  'modul': 1492,
#  'concentr': 600,
#  'project': 1730,
#  'offici': 1587,
#  'england': 796,
#  'poli': 1691,
#  'colour': 584,
#  'flag': 880,
#  'yer': 2483,
#  'tonight': 2243,
#  'tone': 2242,
#  '84199': 187,
#  'optout': 1609,
#  'txt': 2280,
#  'eng': 795,
#  'box39822': 445,
#  'w111wx': 2352,
#  'settl': 1895,
#  'new': 1548,
#  'school': 1864,
#  'year': 2480,
#  'wishin': 2424,
#  'friend': 915,
#  'em': 788,
#  'tot': 2248,
#  'shirt': 1913,
#  'move': 1509,
#  'in2': 1123,
#  'pub': 1735,
#  'cud': 653,
#  'appt': 310,
#  'fault': 853,
#  'twice': 2278,
#  'network': 1545,
#  'technic': 2180,
#  'support': 2126,
#  'ho': 1049,
#  'type': 2285,
#  'word': 2447,
#  'wake': 2360,
#  'long': 1354,
#  'ago': 243,
#  'dunno': 769,
#  'moji': 1493,
#  'inform': 1140,
#  'pass': 1639,
#  'polyphon': 1693,
#  'charg': 538,
#  'appli': 305,
#  'enjoy': 798,
#  'unabl': 2293,
#  'deep': 698,
#  'thanx': 2200,
#  'da': 667,
#  'fone': 890,
#  'cool': 616,
#  'nice': 1553,
#  'readi': 1768,
#  'thursday': 2220,
#  '2day': 103,
#  'kick': 1244,
#  'privat': 1722,
#  '2004': 87,
#  'statement': 2067,
#  'point': 1690,
#  'identifi': 1105,
#  'expir': 834,
#  'stand': 2061,
#  'need': 1541,
#  'coz': 629,
#  'theatr': 2202,
#  'unlimit': 2300,
#  'pay': 1643,
#  'song': 2012,
#  'congrat': 605,
#  '3g': 132,
#  'videophon': 2336,
#  'videochat': 2335,
#  'wid': 2409,
#  'mate': 1433,
#  'java': 1190,
#  'dload': 738,
#  'music': 1525,
#  'nolin': 1563,
#  'rentl': 1802,
#  'bx420': 477,
#  'ip4': 1162,
#  '5we': 161,
#  '150pm': 69,
#  'senthil': 1887,
#  'group': 983,
#  'compani': 594,
#  'dare': 674,
#  'chang': 536,
#  'ring': 1822,
#  'babi': 362,
#  'open': 1603,
#  'pussi': 1741,
#  'alright': 268,
#  'sure': 2130,
#  'sunshin': 2121,
#  'quiz': 1751,
#  'wkli': 2434,
#  'soni': 2013,
#  'dvd': 770,
#  'player': 1677,
#  'countri': 624,
#  'algarv': 259,
#  'ansr': 289,
#  '82277': 182,
#  'sp': 2030,
#  'tyron': 2286,
#  'darren': 678,
#  'consid': 608,
#  'mah': 1413,
#  'elsewher': 787,
#  'test': 2192,
#  'card': 509,
#  'si': 1933,
#  'bath': 375,
#  'disturb': 737,
#  'clean': 569,
#  'night': 1555,
#  'lemm': 1304,
#  'around': 321,
#  'rememb': 1795,
#  'hurt': 1091,
#  'price': 1719,
#  'may': 1441,
#  'pray': 1711,
#  'sura': 2129,
#  'sun': 2117,
#  'tv': 2276,
#  'latest': 1283,
#  'part': 1636,
#  'iq': 1165,
#  'left': 1299,
#  'orchard': 1612,
#  'batteri': 376,
#  'low': 1378,
#  'wherev': 2400,
#  'bu': 464,
#  '800': 173,
#  'land': 1272,
#  'line': 1326,
#  'onlin': 1599,
#  'job': 1204,
#  'bday': 381,
#  'april': 311,
#  'bed': 386,
#  'langport': 1275,
#  'crazi': 637,
#  'auto': 347,
#  'correct': 618,
#  'yesterday': 2485,
#  'await': 353,
#  'deni': 709,
#  'pleas': 1678,
#  'bahama': 367,
#  'callfreefon': 491,
#  '08081560665': 23,
#  'speak': 2034,
#  'oper': 1604,
#  'either': 785,
#  'cruis': 649,
#  '2000': 85,
#  '18': 75,
#  'upset': 2307,
#  'assum': 334,
#  'believ': 395,
#  'wonder': 2444,
#  'plan': 1675,
#  'begin': 391,
#  'later': 1282,
#  'immedi': 1117,
#  'look': 1356,
#  'rock': 1827,
#  'well': 2391,
#  'shop': 1919,
#  'drop': 762,
#  '10k': 48,
#  'travel': 2258,
#  'ntt': 1574,
#  'cr01327bt': 630,
#  'cost': 619,
#  '150ppm': 71,
#  'vari': 2326,
#  'gener': 944,
#  'oz': 1625,
#  'dude': 766,
#  'afraid': 238,
#  'usf': 2319,
#  'guess': 988,
#  'might': 1465,
#  'car': 508,
#  'seem': 1877,
#  'print': 1721,
#  'vote': 2348,
#  'sing': 1948,
#  'along': 266,
#  'star': 2063,
#  'karaok': 1230,
#  '15': 64,
#  'st': 2057,
#  'librari': 1313,
#  'access': 216,
#  'til': 2225,
#  'better': 400,
#  'togeth': 2236,
#  'befor': 389,
#  'kind': 1249,
#  'affair': 236,
#  'accident': 218,
#  'yo': 2490,
#  'carlo': 512,
#  'soon': 2016,
#  'wear': 2379,
#  'teas': 2178,
#  'cri': 644,
#  'die': 720,
#  'plz': 1682,
#  'rose': 1834,
#  'bslvyl': 461,
#  'talk': 2158,
#  'join': 1207,
#  'hun': 1086,
#  'ru': 1839,
#  'met': 1461,
#  'far': 848,
#  'how': 1075,
#  'sux': 2133,
#  'snake': 1993,
#  'old': 1594,
#  'buff': 468,
#  'birla': 409,
#  'soft': 1999,
#  'didnt': 719,
#  'holla': 1056,
#  'base': 373,
#  'system': 2149,
#  'mani': 1425,
#  'sweet': 2138,
#  'fine': 871,
#  'happen': 1002,
#  'smile': 1987,
#  'sometim': 2009,
#  'forget': 898,
#  'noon': 1565,
#  'bugi': 469,
#  'laugh': 1285,
#  'add': 226,
#  'swt': 2146,
#  'dream': 756,
#  'noth': 1571,
#  'bit': 412,
#  'bore': 436,
#  'earli': 772,
#  'lot': 1364,
#  'sigh': 1938,
#  'bar': 371,
#  'ptbo': 1734,
#  'blue': 425,
#  'someth': 2007,
#  'tel': 2182,
#  'stayin': 2071,
#  'extra': 837,
#  'next': 1551,
#  'wed': 2382,
#  'thinkin': 2207,
#  'drug': 763,
#  'sunday': 2118,
#  'holiday': 1055,
#  'work': 2448,
#  'luv': 1392,
#  'soo': 2015,
#  'understand': 2295,
#  '2morrow': 110,
#  'lead': 1293,
#  'bid': 402,
#  'auction': 341,
#  'custom': 661,
#  'infern': 1138,
#  'ate': 335,
#  'slice': 1972,
#  'pizza': 1672,
#  'ugh': 2288,
#  'jd': 1193,
#  'cum': 655,
#  'execut': 829,
#  'id': 1103,
#  'unsold': 2301,
#  'chase': 541,
#  'bought': 441,
#  '2u': 119,
#  'relax': 1792,
#  'past': 1642,
#  'histori': 1040,
#  'sh': 1899,
#  'chennai': 549,
#  'bout': 442,
#  'origin': 1616,
#  'vodafon': 2343,
#  'select': 1879,
#  '350': 129,
#  'match': 1432,
#  '1st': 79,
#  'lunch': 1390,
#  'ge': 942,
#  'asap': 327,
#  'name': 1531,
#  'angri': 283,
#  'mm': 1480,
#  'food': 891,
#  'paid': 1630,
#  'fill': 867,
#  'abiola': 210,
#  'anna': 285,
#  'afternoon': 240,
#  'common': 591,
#  'china': 557,
#  'expens': 832,
#  'hol': 1051,
#  'med': 1447,
#  'envelop': 804,
#  'drink': 760,
#  '113': 52,
#  'wicklow': 2408,
#  'saturday': 1855,
#  'unsub': 2302,
#  'build': 470,
#  'snowman': 1996,
#  'snow': 1995,
#  'fight': 864,
#  'lido': 1315,
#  'babysit': 363,
#  'xx': 2469,
#  '3030': 126,
#  '12hr': 59,
#  'summer': 2115,
#  'flirt': 885,
#  'area': 315,
#  'mark': 1429,
#  'hous': 1073,
#  'mmm': 1481,
#  'yummi': 2495,
#  'jolt': 1210,
#  'suzi': 2134,
#  'hyde': 1095,
#  'park': 1635,
#  'villag': 2339,
#  'dat': 679,
#  'gal': 932,
#  'coffe': 578,
#  'anim': 284,
#  'behav': 392,
#  'india': 1133,
#  'south': 2029,
#  'suck': 2106,
#  'valentin': 2322,
#  'costa': 620,
#  'del': 703,
#  'sol': 2002,
#  '5000': 151,
#  '09050090044': 38,
#  'toclaim': 2234,
#  'sae': 1846,
#  'tc': 2171,
#  'pobox334': 1686,
#  'stockport': 2078,
#  'sk38xh': 1961,
#  'pm': 1683,
#  'max10min': 1439,
#  'invit': 1159,
#  'anywher': 299,
#  'voic': 2345,
#  'process': 1727,
#  'male': 1420,
#  'sale': 1850,
#  'hot': 1070,
#  'gay': 939,
#  'cheaper': 544,
#  'nation': 1535,
#  'rate': 1762,
#  '5p': 158,
#  'cheap': 543,
#  '08712460324': 33,
#  '10p': 49,
#  'princess': 1720,
#  'moan': 1484,
#  'goe': 961,
#  'walk': 2361,
#  'polic': 1692,
#  'lei': 1303,
#  'haf': 993,
#  'amp': 280,
#  'mom': 1494,
#  'stori': 2084,
#  'hiya': 1042,
#  'wot': 2454,
#  'moment': 1495,
#  'hate': 1007,
#  'hell': 1025,
#  'dan': 672,
#  'lookatm': 1357,
#  'purchas': 1737,
#  'video': 2334,
#  'belovd': 397,
#  'goal': 959,
#  'team': 2176,
#  'news': 1550,
#  '87077': 193,
#  'eg': 782,
#  '20': 83,
#  'nvm': 1578,
#  'ah': 244,
#  'sen': 1883,
#  'improv': 1122,
#  'post': 1700,
#  'coupl': 625,
#  'outsid': 1621,
#  'winner': 2419,
#  'valu': 2324,
#  'reward': 1819,
#  'hour': 1072,
#  'derek': 712,
#  'aight': 248,
#  'smoke': 1989,
#  'spend': 2041,
#  'beg': 390,
#  'arriv': 324,
#  'awak': 354,
#  'cold': 580,
#  'cancer': 501,
#  'deal': 685,
#  'regular': 1790,
#  'mono': 1499,
#  'cha': 532,
#  'slide': 1973,
#  'slow': 1978,
#  'put': 1742,
#  'tea': 2173,
#  'excit': 827,
#  'adult': 232,
#  'slept': 1971,
#  'recharg': 1780,
#  'rakhesh': 1757,
#  'busi': 473,
#  'knacker': 1255,
#  'came': 495,
#  'full': 924,
#  'pple': 1707,
#  'excel': 825,
#  'locat': 1345,
#  'wif': 2411,
#  'noe': 1561,
#  'sell': 1881,
#  'close': 573,
#  'entri': 802,
#  'comp': 593,
#  'nokia': 1562,
#  '250': 96,
#  'http': 1082,
#  '08715705022': 34,
#  'made': 1410,
#  'appoint': 306,
#  'camera': 496,
#  'sipix': 1951,
#  'digit': 724,
#  '09061221066': 40,
#  'fromm': 921,
#  'deliveri': 706,
#  'within': 2427,
#  '28': 100,
#  'leh': 1302,
#  'gotta': 972,
#  'nope': 1566,
#  'juz': 1223,
#  'fuck': 922,
#  '25': 95,
#  'giv': 952,
#  'l8r': 1265,
#  'iam': 1096,
#  'shitload': 1915,
#  'mrng': 1513,
#  'hav': 1008,
#  'chechi': 546,
#  'anymor': 293,
#  'kiss': 1254,
#  'awesom': 357,
#  'doin': 746,
#  'major': 1417,
#  'role': 1829,
#  'commun': 592,
#  'anyway': 298,
#  'solv': 2003,
#  'sweeti': 2141,
#  'lover': 1375,
#  'slave': 1968,
#  'across': 221,
#  'sea': 1869,
#  'via': 2333,
#  'must': 1526,
#  'age': 241,
#  'verifi': 2330,
#  'display': 735,
#  'voda': 2342,
#  '08712300220': 31,
#  'quot': 1752,
#  'standard': 2062,
#  'rain': 1754,
#  'caught': 522,
#  'mrt': 1514,
#  'midnight': 1464,
#  'scream': 1866,
#  'hsbc': 1081,
#  'upgrad': 2305,
#  'loyalti': 1380,
#  '0207': 3,
#  '153': 72,
#  '26th': 99,
#  'juli': 1221,
#  'avail': 348,
#  'tmr': 2231,
#  'captain': 507,
#  'comedi': 589,
#  'grand': 976,
#  '10': 42,
#  '28day': 101,
#  'm221bp': 1399,
#  '2yr': 122,
#  ...}

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Classifier = RandomForestClassifier().fit(X_train,y_train)
# Out:
# C:\Users\VIJITK~1\AppData\Local\Temp/ipykernel_3868/2114171994.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Classifier = RandomForestClassifier().fit(X_train,y_train)

# %%
y_pred = Classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[966,   0],
#        [ 18, 131]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9838565022421525

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       966
#            1       1.00      0.88      0.94       149
#
#     accuracy                           0.98      1115
#    macro avg       0.99      0.94      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
pickle.dump(cv,open('vectorize.pkl','wb'))

# %%
pickle.dump(Classifier,open('model.pkl','wb'))

# %%
text = pickle.load(open('vectorize.pkl','rb'))

# %%
vec = text.transform(["'Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's'"]).toarray()

# %%
model = pickle.load(open('model.pkl','rb'))

# %%
model.predict(vec)[0]
# Out:
# 1
